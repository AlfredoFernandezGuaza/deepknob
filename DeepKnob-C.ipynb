# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AlfredoFernandezGuaza/deepknob/blob/master/DeepKnob-C.ipynb)

# %% [markdown]
# **Load Repository**

# %%
# !git clone https://github.com/AlfredoFernandezGuaza/deepknob.git

# %% [markdown]
# # DeepKnob
# User identification from data retrieved by sensors using neural networks.

# %%
import tensorflow
from tensorflow import keras

print('Tensorflow version:', keras.__version__)
# Out:
# Tensorflow version: 2.8.0

# %% [markdown]
# ## Dataset
# Contains:
# <ol style="margin-top:0; font-weight:bold">
#     <li>
#         <span>Header:</span>
#         <span style="font-weight:normal"> user_ID, attempt, time(us), accX(g), accY(g), accZ(g), gyrX(o/s), gyrY(o/s), gyrZ(o/s).</span>
#     </li>
#     <li>
#         <span>Data:</span>
#         <span style="font-weight:normal">NOT normalized data.</span>
#     </li>
#     <li>
#         <span>Empty Line:</span>
#         <span style="font-weight:normal">Last line is empty, so we do not use it.</span>
#     </li>
# </ol>
#
# ### Opening the Dataset
# Getting Data from Dataset

# %%
import os
dir = './content/deepknob'
data_dir = os.path.join(dir, 'data')
fname = os.path.join(data_dir, 'final_dataset.csv')

f = open(fname)
raw_data = f.read()
f.close()

lines = raw_data.split('\n')
lines = lines[:-1]
header = lines[0].split(',')
lines = lines[1:]

print('Number of lines:', len(lines))
print("First line:", lines[0])
print("Last line:", lines[-1])
# Out:
# Number of lines: 1405300
# First line: 1,1,0,1.009766,-0.016602,0.016602,0.900763,0.152672,-0.778626
# Last line: 47,20,2478561,1.009277,0.021484,-0.015137,0.748092,0.076336,-0.48855

# %% [markdown]
# ### Process the Raw Data
# Get list of accelerometer and gyroscope floating point values from row data. \
# Each list item is one measure of the accelerometer and gyrocope in the 3 dimensional axis.

# %%
import numpy as np

float_data = np.zeros((len(lines), len(header)))
for i, line in enumerate(lines):
    values = [float(x) for x in line.split(',')]
    float_data[i, :] = values

first_column = 3 
last_column = 9
columns = last_column - first_column
data = float_data[:,first_column:last_column]

# %% [markdown]
# ### One hot encoding of data labels
# Get the labels of each attempt. \
# One attempt is compose by a number of measures. \
# The label is the user_ID who made the attempt. \
# Then vectorize each label as a vector [0,0,...,0,1,0,...,0,0] which length is the number of different users. \
# Number 1 in the one_hot label vector means the user_ID index who made the attempt.

# %%
from tensorflow.keras.utils import to_categorical

measures_per_attempt = 1495
labels = float_data[::measures_per_attempt, 0]

labels = labels-1
labels = labels.astype('int32')

labels = to_categorical(labels)

# %% [markdown]
# ### Reshape data into shape (samples, timesteps, features)
# The number of classes or categories is each label length, which is the same for every label.\
# The number of attempts is the attempts done by each user, which is the same for every user.\
# The new data consists of 3D tensor which shape is the following:
# <ol style="margin-top:0; font-weight:bold">
#     <li>
#         <span>Samples:</span>
#         <span style="font-weight:normal">How many times every user has done an attempt.</span>
#     </li>
#     <li>
#         <span>Timesteps:</span>
#         <span style="font-weight:normal">How many measures are done in an attempt by one user.</span>
#     </li>
#     <li>
#         <span>Features:</span>
#         <span style="font-weight:normal">The different types of measures done each timestep.</span>
#     </li>
# </ol>

# %%
categories = labels.shape[-1]
attempts = int(float_data[-1, 1])

samples = categories * attempts
sensor_readings = len(lines) // samples

data = data.reshape(samples, sensor_readings, columns)

# %% [markdown]
# ### Remove useless data
# Remove the data of measures taken before the contact with the knob.

# %%
batch_begin = 244

data = data[:,batch_begin:,:]

# %% [markdown]
# ### Plot data
# Show data to know where to cut.

# %%
from matplotlib import pyplot as plt

fig, axs = plt.subplots(figsize=(50, 27))
for i, val in enumerate(data):
	axs.plot(data[i,:,:])
axs.grid=True
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Shuffle users and samples
# Randomize users or categories and for each user shuffle their attempts or samples.\
# Return a tuple with training-validation set and test set indices.

# %%
import random

def getIndices(attempts=20,
               categories=47,
               training_probability=0.6,
               validation_probability=0.2,
               shuffle=True):
    
    training_SPC = attempts * int(training_probability * 100) // 100 
    validation_SPC = attempts * int(validation_probability * 100) // 100
    test_SPC = training_SPC + validation_SPC 
    
    train_indices = []
    validation_indices = []
    test_indices = []
    
    random_indices = [i for i in range(attempts)] 

    shuffled_categories = [i for i in range(categories)]
    if shuffle: random.shuffle(shuffled_categories)
    
    for category in shuffled_categories:
        if shuffle: random.shuffle(random_indices)
        for i in random_indices[:training_SPC]: 
            train_indices.append(attempts * category + i)  
        for i in random_indices[training_SPC:test_SPC]:
            validation_indices.append(attempts * category + i) 
        for i in random_indices[test_SPC:]:
            test_indices.append(attempts * category + i) 

    return (train_indices, validation_indices, test_indices)

(train_indices, validate_indices, test_indices) = getIndices(attempts,
                                                             categories,
                                                             0.6,
                                                             0.2,
                                                             shuffle=True)

# %% [markdown]
# ### Split data into training, validation and testing
# Use the shuffled indices to split data in:
# <ol style="margin-top:0; font-weight:bold">
#     <li>
#         <span>Training:</span>
#         <span style="font-weight:normal">Data which will feed the model.</span>
#     </li>
#     <li>
#         <span>Validation:</span>
#         <span style="font-weight:normal">Data use to tune model hyperparameters.</span>
#     </li>
#     <li>
#         <span>Testing:</span>
#         <span style="font-weight:normal">Data which allows the real model performance.</span>
#     </li>
# </ol>

# %%
x_train = data[train_indices,:,:]
y_train = labels[train_indices,:]

x_validate = data[validate_indices,:,:]
y_validate = labels[validate_indices,:]

x_test = data[test_indices,:,:]
y_test = labels[test_indices,:]

# %% [markdown]
# ## Machine learning approach
# Different layers from Keras layers API are used, layers are the basic block ok neural networks in Keras.
# The used Model layers consists:
# <ul style="margin-top:0; font-weight:bold">
#     <li>
#         <span>Normalization:</span>
#         <span style="font-weight:normal">This layer will shift and scale inputs into a distribution centered around 0 with standard deviation 1.</span>
#     </li>
#     <li>
#         <span>LSTM:</span>
#         <span style="font-weight:normal">Long Short-Term Memory layer, an recurrent neural network which takes into acount time series data.</span>
#     </li>
#     <li>
#         <span>Bidirectional:</span>
#         <span style="font-weight:normal">Wrapper of recurrent neural networks which allows to process data forward (from past to future) and backwards (from future to past).</span>
#     </li>
#     <li>
#         <span>Conv1D:</span>
#         <span style="font-weight:normal">The kernel is a window of specified size. Convolutions are the product of doing mathematical operations, mainly scalar products of kernel window size over the input. A filter is a group of kernels, number of kernels is also specified. This layer produce as many convolutions as filters specified. The goal of this layer is learn spatial hierarchies of patterns.</span>
#     </li>
#     <li>
#         <span>MaxPooling1D:</span>
#         <span style="font-weight:normal">The input is divided by a specified integer, in each section produced by the division produce a float with the max value of the section. The purspose of this layer is to down-sample the input, reducing its dimesionality.</span>
#     </li>
#     <li>
#         <span>GloabalMaxPool1D:</span>
#         <span style="font-weight:normal">Down-samples the input representation by taking the maximum value over the time dimension.</span>
#     </li>
#     <li>
#         <span>Flatten:</span>
#         <span style="font-weight:normal">Flattens the input into shape(none, x), where x is the multiplication of input shapes.</span>
#     </li>
#     <li>
#         <span>Dense:</span>
#         <span style="font-weight:normal">Regular densely-connected neural network layer. Each layer neuron recives input from all previos layer neurons. Then a non-linear transformation is done to produce output.</span>
#     </li>
#     <li>
#         <span>Dropout:</span>
#         <span style="font-weight:normal">Sets randomly input units to 0 with a specified frecuency.</span>
#     </li>
# </ul>

# %%
from keras import Input 
from keras.models import Model
from keras.layers.preprocessing.normalization import Normalization
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPooling1D, GlobalMaxPooling1D
from keras.layers.recurrent import LSTM
from keras.layers.wrappers import Bidirectional
from keras.layers.core import Dense
from keras.activations import relu, softmax

def create_model(x_train, summary=True):
  
  # Preprocessing Normalization
  normalizeLayer = Normalization()
  normalizeLayer.adapt(x_train)

  input_tensor = Input(shape=x_train.shape[1:])
  common_input = normalizeLayer(input_tensor)

  # Recurrent and Covolutional Base
  tensor = Conv1D(47, 7, activation=relu)(common_input)
  tensor = MaxPooling1D(5)(tensor)
  tensor = Conv1D(57, 7, activation=relu)(tensor)
  tensor = MaxPooling1D(3)(tensor)
  tensor = Bidirectional(LSTM(24, dropout=0.2, return_sequences=True))(tensor)
  tensor = GlobalMaxPooling1D()(tensor)
  
  # Classifier
  output_tensor = Dense(47, activation=softmax)(tensor)

  model = Model(input_tensor, output_tensor)

  if summary: model.summary()

  return model

model = create_model(x_train)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1251, 6)]         0
#
#  normalization (Normalizatio  (None, 1251, 6)          13
#  n)
#
#  conv1d (Conv1D)             (None, 1245, 47)          2021
#
#  max_pooling1d (MaxPooling1D  (None, 249, 47)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 243, 57)           18810
#
#  max_pooling1d_1 (MaxPooling  (None, 81, 57)           0
#  1D)
#
#  bidirectional (Bidirectiona  (None, 81, 48)           15744
#  l)
#
#  global_max_pooling1d (Globa  (None, 48)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 47)                2303
#
# =================================================================
# Total params: 38,891
# Trainable params: 38,878
# Non-trainable params: 13
# _________________________________________________________________

# %% [markdown]
# ### Model callbacks
# The model stops training if two conditions are met:
#
# *   Number of epochs with no improvement is greater than an specified variable.
# *   Training loss is less than 0.1 or validation accuracy is greater than threashold.

# %%
from keras.callbacks import Callback, ModelCheckpoint, LearningRateScheduler 

class ThresholdCallback(Callback):
    def __init__(self, threshold, max_loss=0.1, patience=0):
        super(ThresholdCallback, self).__init__()
        self.threshold = threshold
        self.max_loss = max_loss
        self.patience = patience
        
        self.best_weights = None

    def on_train_begin(self, logs=None):
        self.wait = 0
        self.best = np.Inf

    def on_epoch_end(self, epoch, logs=None): 
        val_accuracy = logs.get('val_categorical_accuracy')
        current = logs.get('loss')
        
        if np.less(current, self.best):
            self.best = current
            self.wait = 0
            self.best_weights = self.model.get_weights()
        else:
            self.wait += 1
            is_patience_end = self.wait >= self.patience
            is_out_of_threshold = val_accuracy > self.threshold
            is_less_than_max_loss = current < self.max_loss
            stop = is_patience_end and (is_out_of_threshold or is_less_than_max_loss)
            if stop:
                self.model.stop_training = True
                self.model.set_weights(self.best_weights)
        

models_dir = os.path.join(drive_dir, 'models')
model_path = os.path.join(models_dir, 'deepKnob-C.h5')

threshold = ThresholdCallback(threshold=0.9, patience=1)

checkpoint = ModelCheckpoint(filepath=model_path,
                             monitor='val_categorical_accuracy',
                             save_best_only=True)

def scheduler(epoch, lr):
  if epoch in {60, 80, 100}:
    return lr / 2

  return lr

scheduler = LearningRateScheduler(scheduler)

# %% [markdown]
# ### Compile and fit the model
# Due to DeepKnob is a classification so problem *categorical_crossentropy* is used.

# %%
from tensorflow.keras.optimizers import Adam
from keras.losses import categorical_crossentropy
from keras.metrics import categorical_accuracy

number_of_epochs = 125
number_of_batch_size = 32

model.compile(loss=categorical_crossentropy,
              optimizer=Adam(),
              metrics=[categorical_accuracy])

history = model.fit(x_train,
                    y_train,
                    epochs=number_of_epochs,
                    batch_size=number_of_batch_size,
                    callbacks=[threshold, checkpoint, scheduler],
                    validation_data=(x_validate, y_validate))
# Out:
# Epoch 1/125
# 18/18 [==============================] - 12s 307ms/step - loss: 3.8716 - categorical_accuracy: 0.0213 - val_loss: 3.8240 - val_categorical_accuracy: 0.0372 - lr: 0.0010
# Epoch 2/125
# 18/18 [==============================] - 5s 287ms/step - loss: 3.8304 - categorical_accuracy: 0.0213 - val_loss: 3.8003 - val_categorical_accuracy: 0.0585 - lr: 0.0010
# Epoch 3/125
# 18/18 [==============================] - 5s 292ms/step - loss: 3.8002 - categorical_accuracy: 0.0355 - val_loss: 3.7618 - val_categorical_accuracy: 0.0585 - lr: 0.0010
# Epoch 4/125
# 18/18 [==============================] - 4s 249ms/step - loss: 3.7526 - categorical_accuracy: 0.0496 - val_loss: 3.6981 - val_categorical_accuracy: 0.1011 - lr: 0.0010
# Epoch 5/125
# 18/18 [==============================] - 4s 240ms/step - loss: 3.6675 - categorical_accuracy: 0.0709 - val_loss: 3.5831 - val_categorical_accuracy: 0.0957 - lr: 0.0010
# Epoch 6/125
# 18/18 [==============================] - 5s 255ms/step - loss: 3.5741 - categorical_accuracy: 0.0993 - val_loss: 3.4672 - val_categorical_accuracy: 0.1702 - lr: 0.0010
# Epoch 7/125
# 18/18 [==============================] - 4s 245ms/step - loss: 3.4289 - categorical_accuracy: 0.1454 - val_loss: 3.3227 - val_categorical_accuracy: 0.2394 - lr: 0.0010
# Epoch 8/125
# 18/18 [==============================] - 4s 247ms/step - loss: 3.2871 - categorical_accuracy: 0.2252 - val_loss: 3.1445 - val_categorical_accuracy: 0.2926 - lr: 0.0010
# Epoch 9/125
# 18/18 [==============================] - 4s 242ms/step - loss: 3.1023 - categorical_accuracy: 0.3050 - val_loss: 2.9452 - val_categorical_accuracy: 0.4043 - lr: 0.0010
# Epoch 10/125
# 18/18 [==============================] - 4s 242ms/step - loss: 2.9048 - categorical_accuracy: 0.3741 - val_loss: 2.7701 - val_categorical_accuracy: 0.4202 - lr: 0.0010
# Epoch 11/125
# 18/18 [==============================] - 4s 246ms/step - loss: 2.7640 - categorical_accuracy: 0.3972 - val_loss: 2.5965 - val_categorical_accuracy: 0.5106 - lr: 0.0010
# Epoch 12/125
# 18/18 [==============================] - 5s 255ms/step - loss: 2.5622 - categorical_accuracy: 0.4752 - val_loss: 2.4476 - val_categorical_accuracy: 0.5372 - lr: 0.0010
# Epoch 13/125
# 18/18 [==============================] - 4s 249ms/step - loss: 2.4005 - categorical_accuracy: 0.5461 - val_loss: 2.3521 - val_categorical_accuracy: 0.5372 - lr: 0.0010
# Epoch 14/125
# 18/18 [==============================] - 7s 382ms/step - loss: 2.2573 - categorical_accuracy: 0.6135 - val_loss: 2.1790 - val_categorical_accuracy: 0.5479 - lr: 0.0010
# Epoch 15/125
# 18/18 [==============================] - 4s 246ms/step - loss: 2.0836 - categorical_accuracy: 0.6188 - val_loss: 1.9686 - val_categorical_accuracy: 0.6915 - lr: 0.0010
# Epoch 16/125
# 18/18 [==============================] - 4s 243ms/step - loss: 1.9331 - categorical_accuracy: 0.6862 - val_loss: 1.8500 - val_categorical_accuracy: 0.7074 - lr: 0.0010
# Epoch 17/125
# 18/18 [==============================] - 4s 245ms/step - loss: 1.8347 - categorical_accuracy: 0.6684 - val_loss: 1.7147 - val_categorical_accuracy: 0.6809 - lr: 0.0010
# Epoch 18/125
# 18/18 [==============================] - 4s 246ms/step - loss: 1.7036 - categorical_accuracy: 0.7092 - val_loss: 1.6243 - val_categorical_accuracy: 0.7074 - lr: 0.0010
# Epoch 19/125
# 18/18 [==============================] - 5s 255ms/step - loss: 1.6046 - categorical_accuracy: 0.7163 - val_loss: 1.5207 - val_categorical_accuracy: 0.7234 - lr: 0.0010
# Epoch 20/125
# 18/18 [==============================] - 4s 238ms/step - loss: 1.5238 - categorical_accuracy: 0.7394 - val_loss: 1.4965 - val_categorical_accuracy: 0.6968 - lr: 0.0010
# Epoch 21/125
# 18/18 [==============================] - 5s 258ms/step - loss: 1.3981 - categorical_accuracy: 0.7801 - val_loss: 1.4173 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 22/125
# 18/18 [==============================] - 5s 252ms/step - loss: 1.4195 - categorical_accuracy: 0.7606 - val_loss: 1.4248 - val_categorical_accuracy: 0.7287 - lr: 0.0010
# Epoch 23/125
# 18/18 [==============================] - 5s 258ms/step - loss: 1.2966 - categorical_accuracy: 0.7801 - val_loss: 1.2878 - val_categorical_accuracy: 0.7606 - lr: 0.0010
# Epoch 24/125
# 18/18 [==============================] - 4s 250ms/step - loss: 1.2206 - categorical_accuracy: 0.8103 - val_loss: 1.1968 - val_categorical_accuracy: 0.7713 - lr: 0.0010
# Epoch 25/125
# 18/18 [==============================] - 4s 245ms/step - loss: 1.1637 - categorical_accuracy: 0.8121 - val_loss: 1.1937 - val_categorical_accuracy: 0.7926 - lr: 0.0010
# Epoch 26/125
# 18/18 [==============================] - 5s 252ms/step - loss: 1.0825 - categorical_accuracy: 0.8298 - val_loss: 1.1580 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 27/125
# 18/18 [==============================] - 4s 249ms/step - loss: 1.0401 - categorical_accuracy: 0.8280 - val_loss: 1.0679 - val_categorical_accuracy: 0.7819 - lr: 0.0010
# Epoch 28/125
# 18/18 [==============================] - 4s 248ms/step - loss: 0.9485 - categorical_accuracy: 0.8759 - val_loss: 1.0396 - val_categorical_accuracy: 0.7872 - lr: 0.0010
# Epoch 29/125
# 18/18 [==============================] - 4s 248ms/step - loss: 0.9063 - categorical_accuracy: 0.8599 - val_loss: 1.0047 - val_categorical_accuracy: 0.7926 - lr: 0.0010
# Epoch 30/125
# 18/18 [==============================] - 5s 264ms/step - loss: 0.8496 - categorical_accuracy: 0.8688 - val_loss: 0.9936 - val_categorical_accuracy: 0.7979 - lr: 0.0010
# Epoch 31/125
# 18/18 [==============================] - 5s 254ms/step - loss: 0.8579 - categorical_accuracy: 0.8670 - val_loss: 0.9488 - val_categorical_accuracy: 0.8191 - lr: 0.0010
# Epoch 32/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.7795 - categorical_accuracy: 0.8972 - val_loss: 0.9298 - val_categorical_accuracy: 0.8138 - lr: 0.0010
# Epoch 33/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.7636 - categorical_accuracy: 0.8972 - val_loss: 0.8462 - val_categorical_accuracy: 0.8191 - lr: 0.0010
# Epoch 34/125
# 18/18 [==============================] - 4s 240ms/step - loss: 0.7195 - categorical_accuracy: 0.8812 - val_loss: 0.8526 - val_categorical_accuracy: 0.8138 - lr: 0.0010
# Epoch 35/125
# 18/18 [==============================] - 5s 253ms/step - loss: 0.6763 - categorical_accuracy: 0.9184 - val_loss: 0.8188 - val_categorical_accuracy: 0.8511 - lr: 0.0010
# Epoch 36/125
# 18/18 [==============================] - 4s 244ms/step - loss: 0.6590 - categorical_accuracy: 0.9184 - val_loss: 0.7782 - val_categorical_accuracy: 0.8404 - lr: 0.0010
# Epoch 37/125
# 18/18 [==============================] - 4s 245ms/step - loss: 0.6224 - categorical_accuracy: 0.9273 - val_loss: 0.7700 - val_categorical_accuracy: 0.8298 - lr: 0.0010
# Epoch 38/125
# 18/18 [==============================] - 4s 245ms/step - loss: 0.5966 - categorical_accuracy: 0.9397 - val_loss: 0.7401 - val_categorical_accuracy: 0.8245 - lr: 0.0010
# Epoch 39/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.5723 - categorical_accuracy: 0.9486 - val_loss: 0.7270 - val_categorical_accuracy: 0.8404 - lr: 0.0010
# Epoch 40/125
# 18/18 [==============================] - 4s 242ms/step - loss: 0.5387 - categorical_accuracy: 0.9521 - val_loss: 0.7051 - val_categorical_accuracy: 0.8404 - lr: 0.0010
# Epoch 41/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.5333 - categorical_accuracy: 0.9220 - val_loss: 0.7358 - val_categorical_accuracy: 0.8404 - lr: 0.0010
# Epoch 42/125
# 18/18 [==============================] - 4s 242ms/step - loss: 0.4997 - categorical_accuracy: 0.9521 - val_loss: 0.7214 - val_categorical_accuracy: 0.8351 - lr: 0.0010
# Epoch 43/125
# 18/18 [==============================] - 4s 244ms/step - loss: 0.4878 - categorical_accuracy: 0.9592 - val_loss: 0.6810 - val_categorical_accuracy: 0.8457 - lr: 0.0010
# Epoch 44/125
# 18/18 [==============================] - 4s 245ms/step - loss: 0.4585 - categorical_accuracy: 0.9486 - val_loss: 0.6591 - val_categorical_accuracy: 0.8457 - lr: 0.0010
# Epoch 45/125
# 18/18 [==============================] - 5s 262ms/step - loss: 0.4617 - categorical_accuracy: 0.9486 - val_loss: 0.6465 - val_categorical_accuracy: 0.8723 - lr: 0.0010
# Epoch 46/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.4563 - categorical_accuracy: 0.9415 - val_loss: 0.6545 - val_categorical_accuracy: 0.8511 - lr: 0.0010
# Epoch 47/125
# 18/18 [==============================] - 5s 252ms/step - loss: 0.4414 - categorical_accuracy: 0.9592 - val_loss: 0.6370 - val_categorical_accuracy: 0.8617 - lr: 0.0010
# Epoch 48/125
# 18/18 [==============================] - 4s 249ms/step - loss: 0.4555 - categorical_accuracy: 0.9433 - val_loss: 0.6498 - val_categorical_accuracy: 0.8404 - lr: 0.0010
# Epoch 49/125
# 18/18 [==============================] - 4s 247ms/step - loss: 0.4104 - categorical_accuracy: 0.9752 - val_loss: 0.6359 - val_categorical_accuracy: 0.8564 - lr: 0.0010
# Epoch 50/125
# 18/18 [==============================] - 4s 246ms/step - loss: 0.3852 - categorical_accuracy: 0.9699 - val_loss: 0.6314 - val_categorical_accuracy: 0.8298 - lr: 0.0010
# Epoch 51/125
# 18/18 [==============================] - 4s 248ms/step - loss: 0.3722 - categorical_accuracy: 0.9752 - val_loss: 0.6181 - val_categorical_accuracy: 0.8404 - lr: 0.0010
# Epoch 52/125
# 18/18 [==============================] - 4s 246ms/step - loss: 0.3375 - categorical_accuracy: 0.9823 - val_loss: 0.6032 - val_categorical_accuracy: 0.8511 - lr: 0.0010
# Epoch 53/125
# 18/18 [==============================] - 4s 245ms/step - loss: 0.3370 - categorical_accuracy: 0.9734 - val_loss: 0.6167 - val_categorical_accuracy: 0.8404 - lr: 0.0010
# Epoch 54/125
# 18/18 [==============================] - 4s 244ms/step - loss: 0.3328 - categorical_accuracy: 0.9770 - val_loss: 0.5956 - val_categorical_accuracy: 0.8670 - lr: 0.0010
# Epoch 55/125
# 18/18 [==============================] - 4s 244ms/step - loss: 0.3244 - categorical_accuracy: 0.9752 - val_loss: 0.5417 - val_categorical_accuracy: 0.8564 - lr: 0.0010
# Epoch 56/125
# 18/18 [==============================] - 5s 259ms/step - loss: 0.3088 - categorical_accuracy: 0.9699 - val_loss: 0.5797 - val_categorical_accuracy: 0.8777 - lr: 0.0010
# Epoch 57/125
# 18/18 [==============================] - 4s 248ms/step - loss: 0.2922 - categorical_accuracy: 0.9823 - val_loss: 0.5525 - val_categorical_accuracy: 0.8723 - lr: 0.0010
# Epoch 58/125
# 18/18 [==============================] - 4s 245ms/step - loss: 0.2837 - categorical_accuracy: 0.9876 - val_loss: 0.5504 - val_categorical_accuracy: 0.8617 - lr: 0.0010
# Epoch 59/125
# 18/18 [==============================] - 4s 242ms/step - loss: 0.2676 - categorical_accuracy: 0.9840 - val_loss: 0.5088 - val_categorical_accuracy: 0.8777 - lr: 0.0010
# Epoch 60/125
# 18/18 [==============================] - 6s 353ms/step - loss: 0.2669 - categorical_accuracy: 0.9787 - val_loss: 0.5515 - val_categorical_accuracy: 0.8723 - lr: 0.0010
# Epoch 61/125
# 18/18 [==============================] - 4s 246ms/step - loss: 0.2430 - categorical_accuracy: 0.9894 - val_loss: 0.5241 - val_categorical_accuracy: 0.8723 - lr: 5.0000e-04
# Epoch 62/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.2249 - categorical_accuracy: 0.9947 - val_loss: 0.5113 - val_categorical_accuracy: 0.8723 - lr: 5.0000e-04
# Epoch 63/125
# 18/18 [==============================] - 5s 255ms/step - loss: 0.2156 - categorical_accuracy: 0.9911 - val_loss: 0.4854 - val_categorical_accuracy: 0.8936 - lr: 5.0000e-04
# Epoch 64/125
# 18/18 [==============================] - 4s 245ms/step - loss: 0.2210 - categorical_accuracy: 0.9947 - val_loss: 0.5073 - val_categorical_accuracy: 0.8830 - lr: 5.0000e-04
# Epoch 65/125
# 18/18 [==============================] - 4s 246ms/step - loss: 0.2194 - categorical_accuracy: 0.9911 - val_loss: 0.5125 - val_categorical_accuracy: 0.8723 - lr: 5.0000e-04
# Epoch 66/125
# 18/18 [==============================] - 4s 245ms/step - loss: 0.2085 - categorical_accuracy: 0.9929 - val_loss: 0.5120 - val_categorical_accuracy: 0.8670 - lr: 5.0000e-04
# Epoch 67/125
# 18/18 [==============================] - 4s 246ms/step - loss: 0.2084 - categorical_accuracy: 0.9929 - val_loss: 0.4763 - val_categorical_accuracy: 0.8883 - lr: 5.0000e-04
# Epoch 68/125
# 18/18 [==============================] - 4s 245ms/step - loss: 0.2070 - categorical_accuracy: 0.9894 - val_loss: 0.4932 - val_categorical_accuracy: 0.8830 - lr: 5.0000e-04
# Epoch 69/125
# 18/18 [==============================] - 4s 246ms/step - loss: 0.2031 - categorical_accuracy: 0.9894 - val_loss: 0.4877 - val_categorical_accuracy: 0.8564 - lr: 5.0000e-04
# Epoch 70/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.1890 - categorical_accuracy: 0.9947 - val_loss: 0.4768 - val_categorical_accuracy: 0.8777 - lr: 5.0000e-04
# Epoch 71/125
# 18/18 [==============================] - 4s 240ms/step - loss: 0.1901 - categorical_accuracy: 0.9947 - val_loss: 0.4941 - val_categorical_accuracy: 0.8883 - lr: 5.0000e-04
# Epoch 72/125
# 18/18 [==============================] - 4s 241ms/step - loss: 0.1888 - categorical_accuracy: 0.9947 - val_loss: 0.4873 - val_categorical_accuracy: 0.8830 - lr: 5.0000e-04
# Epoch 73/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.1859 - categorical_accuracy: 0.9965 - val_loss: 0.4816 - val_categorical_accuracy: 0.8777 - lr: 5.0000e-04
# Epoch 74/125
# 18/18 [==============================] - 4s 241ms/step - loss: 0.1818 - categorical_accuracy: 0.9929 - val_loss: 0.4944 - val_categorical_accuracy: 0.8830 - lr: 5.0000e-04
# Epoch 75/125
# 18/18 [==============================] - 4s 244ms/step - loss: 0.1935 - categorical_accuracy: 0.9894 - val_loss: 0.5800 - val_categorical_accuracy: 0.8351 - lr: 5.0000e-04
# Epoch 76/125
# 18/18 [==============================] - 4s 241ms/step - loss: 0.2335 - categorical_accuracy: 0.9805 - val_loss: 0.4738 - val_categorical_accuracy: 0.8670 - lr: 5.0000e-04
# Epoch 77/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.1947 - categorical_accuracy: 0.9947 - val_loss: 0.4881 - val_categorical_accuracy: 0.8617 - lr: 5.0000e-04
# Epoch 78/125
# 18/18 [==============================] - 4s 245ms/step - loss: 0.1911 - categorical_accuracy: 0.9876 - val_loss: 0.5079 - val_categorical_accuracy: 0.8723 - lr: 5.0000e-04
# Epoch 79/125
# 18/18 [==============================] - 4s 242ms/step - loss: 0.1677 - categorical_accuracy: 0.9965 - val_loss: 0.4870 - val_categorical_accuracy: 0.8777 - lr: 5.0000e-04
# Epoch 80/125
# 18/18 [==============================] - 4s 241ms/step - loss: 0.1676 - categorical_accuracy: 0.9929 - val_loss: 0.4671 - val_categorical_accuracy: 0.8670 - lr: 5.0000e-04
# Epoch 81/125
# 18/18 [==============================] - 4s 242ms/step - loss: 0.1636 - categorical_accuracy: 0.9911 - val_loss: 0.4652 - val_categorical_accuracy: 0.8883 - lr: 2.5000e-04
# Epoch 82/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.1610 - categorical_accuracy: 0.9929 - val_loss: 0.4516 - val_categorical_accuracy: 0.8883 - lr: 2.5000e-04
# Epoch 83/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.1557 - categorical_accuracy: 0.9947 - val_loss: 0.4463 - val_categorical_accuracy: 0.8883 - lr: 2.5000e-04
# Epoch 84/125
# 18/18 [==============================] - 4s 242ms/step - loss: 0.1562 - categorical_accuracy: 0.9965 - val_loss: 0.4417 - val_categorical_accuracy: 0.8830 - lr: 2.5000e-04
# Epoch 85/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.1500 - categorical_accuracy: 0.9965 - val_loss: 0.4693 - val_categorical_accuracy: 0.8777 - lr: 2.5000e-04
# Epoch 86/125
# 18/18 [==============================] - 4s 241ms/step - loss: 0.1547 - categorical_accuracy: 0.9947 - val_loss: 0.4474 - val_categorical_accuracy: 0.8723 - lr: 2.5000e-04
# Epoch 87/125
# 18/18 [==============================] - 4s 245ms/step - loss: 0.1496 - categorical_accuracy: 0.9965 - val_loss: 0.4498 - val_categorical_accuracy: 0.8777 - lr: 2.5000e-04
# Epoch 88/125
# 18/18 [==============================] - 4s 244ms/step - loss: 0.1514 - categorical_accuracy: 0.9947 - val_loss: 0.4413 - val_categorical_accuracy: 0.8830 - lr: 2.5000e-04
# Epoch 89/125
# 18/18 [==============================] - 4s 241ms/step - loss: 0.1455 - categorical_accuracy: 0.9965 - val_loss: 0.4575 - val_categorical_accuracy: 0.8777 - lr: 2.5000e-04
# Epoch 90/125
# 18/18 [==============================] - 4s 242ms/step - loss: 0.1388 - categorical_accuracy: 0.9965 - val_loss: 0.4685 - val_categorical_accuracy: 0.8777 - lr: 2.5000e-04
# Epoch 91/125
# 18/18 [==============================] - 4s 242ms/step - loss: 0.1503 - categorical_accuracy: 0.9929 - val_loss: 0.4671 - val_categorical_accuracy: 0.8830 - lr: 2.5000e-04
# Epoch 92/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.1432 - categorical_accuracy: 0.9965 - val_loss: 0.4483 - val_categorical_accuracy: 0.8883 - lr: 2.5000e-04
# Epoch 93/125
# 18/18 [==============================] - 4s 246ms/step - loss: 0.1389 - categorical_accuracy: 0.9965 - val_loss: 0.4354 - val_categorical_accuracy: 0.8830 - lr: 2.5000e-04
# Epoch 94/125
# 18/18 [==============================] - 5s 252ms/step - loss: 0.1456 - categorical_accuracy: 0.9929 - val_loss: 0.4360 - val_categorical_accuracy: 0.8936 - lr: 2.5000e-04
# Epoch 95/125
# 18/18 [==============================] - 4s 247ms/step - loss: 0.1381 - categorical_accuracy: 0.9947 - val_loss: 0.4469 - val_categorical_accuracy: 0.8830 - lr: 2.5000e-04
# Epoch 96/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.1346 - categorical_accuracy: 0.9947 - val_loss: 0.4411 - val_categorical_accuracy: 0.8883 - lr: 2.5000e-04
# Epoch 97/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.1328 - categorical_accuracy: 0.9965 - val_loss: 0.4394 - val_categorical_accuracy: 0.8883 - lr: 2.5000e-04
# Epoch 98/125
# 18/18 [==============================] - 4s 246ms/step - loss: 0.1350 - categorical_accuracy: 0.9965 - val_loss: 0.4522 - val_categorical_accuracy: 0.8777 - lr: 2.5000e-04
# Epoch 99/125
# 18/18 [==============================] - 4s 244ms/step - loss: 0.1358 - categorical_accuracy: 0.9965 - val_loss: 0.4390 - val_categorical_accuracy: 0.8830 - lr: 2.5000e-04
# Epoch 100/125
# 18/18 [==============================] - 4s 244ms/step - loss: 0.1304 - categorical_accuracy: 0.9965 - val_loss: 0.4389 - val_categorical_accuracy: 0.8777 - lr: 2.5000e-04
# Epoch 101/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.1306 - categorical_accuracy: 0.9947 - val_loss: 0.4411 - val_categorical_accuracy: 0.8883 - lr: 1.2500e-04
# Epoch 102/125
# 18/18 [==============================] - 5s 251ms/step - loss: 0.1330 - categorical_accuracy: 0.9965 - val_loss: 0.4525 - val_categorical_accuracy: 0.8883 - lr: 1.2500e-04
# Epoch 103/125
# 18/18 [==============================] - 4s 249ms/step - loss: 0.1287 - categorical_accuracy: 0.9929 - val_loss: 0.4450 - val_categorical_accuracy: 0.8883 - lr: 1.2500e-04
# Epoch 104/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.1226 - categorical_accuracy: 0.9965 - val_loss: 0.4459 - val_categorical_accuracy: 0.8830 - lr: 1.2500e-04
# Epoch 105/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.1237 - categorical_accuracy: 0.9965 - val_loss: 0.4456 - val_categorical_accuracy: 0.8777 - lr: 1.2500e-04
# Epoch 106/125
# 18/18 [==============================] - 4s 247ms/step - loss: 0.1265 - categorical_accuracy: 0.9965 - val_loss: 0.4467 - val_categorical_accuracy: 0.8830 - lr: 1.2500e-04
# Epoch 107/125
# 18/18 [==============================] - 4s 245ms/step - loss: 0.1240 - categorical_accuracy: 0.9965 - val_loss: 0.4491 - val_categorical_accuracy: 0.8777 - lr: 1.2500e-04
# Epoch 108/125
# 18/18 [==============================] - 4s 243ms/step - loss: 0.1270 - categorical_accuracy: 0.9947 - val_loss: 0.4486 - val_categorical_accuracy: 0.8883 - lr: 1.2500e-04
# Epoch 109/125
# 18/18 [==============================] - 4s 242ms/step - loss: 0.1264 - categorical_accuracy: 0.9947 - val_loss: 0.4531 - val_categorical_accuracy: 0.8830 - lr: 1.2500e-04
# Epoch 110/125
# 18/18 [==============================] - 4s 248ms/step - loss: 0.1235 - categorical_accuracy: 0.9965 - val_loss: 0.4445 - val_categorical_accuracy: 0.8883 - lr: 1.2500e-04
# Epoch 111/125
# 18/18 [==============================] - 4s 244ms/step - loss: 0.1272 - categorical_accuracy: 0.9947 - val_loss: 0.4559 - val_categorical_accuracy: 0.8936 - lr: 1.2500e-04
# Epoch 112/125
# 18/18 [==============================] - 4s 244ms/step - loss: 0.1226 - categorical_accuracy: 0.9965 - val_loss: 0.4603 - val_categorical_accuracy: 0.8777 - lr: 1.2500e-04
# Epoch 113/125
# 18/18 [==============================] - 4s 241ms/step - loss: 0.1203 - categorical_accuracy: 0.9965 - val_loss: 0.4534 - val_categorical_accuracy: 0.8777 - lr: 1.2500e-04
# Epoch 114/125
# 18/18 [==============================] - 4s 248ms/step - loss: 0.1231 - categorical_accuracy: 0.9965 - val_loss: 0.4394 - val_categorical_accuracy: 0.8830 - lr: 1.2500e-04
# Epoch 115/125
# 18/18 [==============================] - 4s 246ms/step - loss: 0.1194 - categorical_accuracy: 0.9965 - val_loss: 0.4291 - val_categorical_accuracy: 0.8883 - lr: 1.2500e-04
# Epoch 116/125
# 18/18 [==============================] - 4s 245ms/step - loss: 0.1216 - categorical_accuracy: 0.9965 - val_loss: 0.4410 - val_categorical_accuracy: 0.8830 - lr: 1.2500e-04
# Epoch 117/125
# 18/18 [==============================] - 4s 242ms/step - loss: 0.1211 - categorical_accuracy: 0.9965 - val_loss: 0.4366 - val_categorical_accuracy: 0.8777 - lr: 1.2500e-04
# Epoch 118/125
# 18/18 [==============================] - 4s 246ms/step - loss: 0.1143 - categorical_accuracy: 0.9965 - val_loss: 0.4382 - val_categorical_accuracy: 0.8777 - lr: 1.2500e-04
# Epoch 119/125
# 18/18 [==============================] - 5s 274ms/step - loss: 0.1198 - categorical_accuracy: 0.9965 - val_loss: 0.4325 - val_categorical_accuracy: 0.8830 - lr: 1.2500e-04
# Epoch 120/125
# 18/18 [==============================] - 5s 251ms/step - loss: 0.1142 - categorical_accuracy: 0.9965 - val_loss: 0.4299 - val_categorical_accuracy: 0.8830 - lr: 1.2500e-04
# Epoch 121/125
# 18/18 [==============================] - 4s 245ms/step - loss: 0.1128 - categorical_accuracy: 0.9965 - val_loss: 0.4241 - val_categorical_accuracy: 0.8830 - lr: 1.2500e-04
# Epoch 122/125
# 18/18 [==============================] - 5s 257ms/step - loss: 0.1139 - categorical_accuracy: 0.9947 - val_loss: 0.4364 - val_categorical_accuracy: 0.8936 - lr: 1.2500e-04
# Epoch 123/125
# 18/18 [==============================] - 5s 255ms/step - loss: 0.1200 - categorical_accuracy: 0.9965 - val_loss: 0.4387 - val_categorical_accuracy: 0.8883 - lr: 1.2500e-04
# Epoch 124/125
# 18/18 [==============================] - 5s 258ms/step - loss: 0.1170 - categorical_accuracy: 0.9965 - val_loss: 0.4494 - val_categorical_accuracy: 0.8883 - lr: 1.2500e-04
# Epoch 125/125
# 18/18 [==============================] - 4s 244ms/step - loss: 0.1182 - categorical_accuracy: 0.9965 - val_loss: 0.4458 - val_categorical_accuracy: 0.8883 - lr: 1.2500e-04

# %% [markdown]
# ### A way to get a smoth curve
# Each point from a list is treated in order to show a smoth curve if it is plotted in a graph.

# %%
def smooth_curve(points, factor=0.9):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# %% [markdown]
# ### Model loss and validation loss
# If loss ≈ validation loss, there is no overfitting neither underfitting.\
# If loss < validation loss, there is overfitting.\
# If loss > validation loss, there is underfitting.

# %%
loss = smooth_curve(history.history['loss'])
val_loss = smooth_curve(history.history['val_loss'])

epochs = range(len(loss))

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ### Model accuracy and validation accuracy
# Accuracy shows the probability of identify the right user.

# %%
val_accur = smooth_curve(history.history['val_categorical_accuracy'])
accur = smooth_curve(history.history['categorical_accuracy'])

plt.figure()

plt.plot(epochs, accur, 'ro', label='Training acc')
plt.plot(epochs, val_accur, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ## Evaluation on test data
# Shows how well the model generalize

# %%
model = keras.models.load_model(model_path)

model.evaluate(x_test, y_test)
# Out:
# 6/6 [==============================] - 1s 44ms/step - loss: 0.5295 - categorical_accuracy: 0.8830
# [0.5294845104217529, 0.8829787373542786]

# %% [markdown]
# ### Confusion Matrix
# Is displayed a matrix which shows if each attempt has been right or if it is being recognized by other user. \
# If the attempt is inside the diagonal, the attempt was rigth.

# %%
from sklearn.metrics import ConfusionMatrixDisplay

y_predictions = model.predict(x_test)

fig, ax = plt.subplots(figsize=(20, 20))

confusion_matrix = ConfusionMatrixDisplay.from_predictions(
    tensorflow.argmax(y_test, 1),
    tensorflow.argmax(y_predictions,1),
    display_labels=[i for i in range(47)],
    cmap=plt.cm.Blues,
    normalize=None,
    ax=ax
)
confusion_matrix.ax_.set_title("Normalized confusion matrix")

plt.show()

# %% [markdown]
# ### More evaluation metrics
# Shows for each user id:
#
# *   True positive rate.
# *   True negative rate.
# *   False positive rate.
# *   False negative rate.
# *   Overall acurracy.

# %%
FP = confusion_matrix.confusion_matrix.sum(axis=0) - np.diag(confusion_matrix.confusion_matrix)  
FN = confusion_matrix.confusion_matrix.sum(axis=1) - np.diag(confusion_matrix.confusion_matrix)
TP = np.diag(confusion_matrix.confusion_matrix)
TN = confusion_matrix.confusion_matrix.sum() - (FP + FN + TP)

matrix = np.zeros((47,5))
print('User_Id'+'\t\t '+'TPR'+'\t '+'TNR'+'\t '+'FPR'+'\t '+'FNR'+'\t '+'ACC')
print('-----------------------------------------------------')
for i in range(47):
    # Sensitivity, hit rate, recall, or true positive rate
    TPR = TP[i]/(TP[i]+FN[i])
    matrix[i,0] = TPR
    # Specificity or true negative rate
    TNR = TN[i]/(TN[i]+FP[i])
    matrix[i,1] = TNR
    # Fall out or false positive rate
    FPR = FP[i]/(FP[i]+TN[i])
    matrix[i,2] = FPR
    # False negative rate
    FNR = FN[i]/(TP[i]+FN[i])
    matrix[i,3] = FNR

    # Overall accuracy
    ACC = (TP[i]+TN[i])/(TP[i]+FP[i]+FN[i]+TN[i])
    matrix[i,4] = ACC
    print('user_id',i , '\t', *[str(round(i,2))+'\t' for i in matrix[i,:]])
# Out:
# User_Id		 TPR	 TNR	 FPR	 FNR	 ACC
# -----------------------------------------------------
# user_id 0 	 0.75	 0.99	 0.01	 0.25	 0.99
# user_id 1 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 2 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 3 	 1.0	 0.99	 0.01	 0.0	 0.99
# user_id 4 	 1.0	 0.99	 0.01	 0.0	 0.99
# user_id 5 	 0.75	 0.99	 0.01	 0.25	 0.99
# user_id 6 	 0.25	 0.99	 0.01	 0.75	 0.97
# user_id 7 	 0.75	 1.0	 0.0	 0.25	 0.99
# user_id 8 	 0.75	 0.99	 0.01	 0.25	 0.99
# user_id 9 	 0.75	 0.99	 0.01	 0.25	 0.98
# user_id 10 	 0.75	 0.99	 0.01	 0.25	 0.99
# user_id 11 	 1.0	 0.99	 0.01	 0.0	 0.99
# user_id 12 	 1.0	 0.99	 0.01	 0.0	 0.99
# user_id 13 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 14 	 0.5	 0.99	 0.01	 0.5	 0.98
# user_id 15 	 0.5	 0.99	 0.01	 0.5	 0.98
# user_id 16 	 0.25	 0.99	 0.01	 0.75	 0.98
# user_id 17 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 18 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 19 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 20 	 0.75	 0.99	 0.01	 0.25	 0.99
# user_id 21 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 22 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 23 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 24 	 0.75	 0.99	 0.01	 0.25	 0.98
# user_id 25 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 26 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 27 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 28 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 29 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 30 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 31 	 0.75	 1.0	 0.0	 0.25	 0.99
# user_id 32 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 33 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 34 	 0.75	 0.99	 0.01	 0.25	 0.99
# user_id 35 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 36 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 37 	 0.75	 1.0	 0.0	 0.25	 0.99
# user_id 38 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 39 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 40 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 41 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 42 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 43 	 1.0	 0.99	 0.01	 0.0	 0.99
# user_id 44 	 0.75	 1.0	 0.0	 0.25	 0.99
# user_id 45 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 46 	 1.0	 0.99	 0.01	 0.0	 0.99

# %% [markdown]
# ## Iterative k-fold evaluation
# 1.   Shuffle users and samples.
# 2.   Split data into two subsets (folds, tests). The folds subset contains k subsets.
# 3.   Use k-1 subsets to train the model and 1 subset for validation, evaluating on tests.
# 4.   Repeat k times step 3 using a diferent validation subset.
# 5.   Go to step 1 and repeat the process as many times as you want.
# 6.   Get average results.

# %% [markdown]
# ### Split data into folds and tests
# Shuffle data and then create balance subsets.

# %%
def get_folds(attempts=20, categories=47, k=4,
              tests_probability=0.2, shuffle=True):
    
    test_attempts = attempts * int(tests_probability * 100) // 100 
    training_and_validation_attempts = attempts - test_attempts 
    
    step = training_and_validation_attempts // k

    folds = [ [] for _ in range(k) ]
    test_indices = []
    
    shuffled_attempts = [i for i in range(attempts)] 

    shuffled_categories = [i for i in range(categories)]
    if shuffle: random.shuffle(shuffled_categories)
    
    for category in shuffled_categories:
        if shuffle: random.shuffle(shuffled_attempts)
        fold_index = 0
        for j in range(0, training_and_validation_attempts, step):
          for i in shuffled_attempts[j:j+step]: 
            folds[fold_index].append(attempts * category + i)  
          fold_index += 1
        for i in shuffled_attempts[training_and_validation_attempts:]:
            test_indices.append(attempts * category + i) 

    return (folds, test_indices)

# %% [markdown]
# ### K-fold
# Add validation loss and validation accuracy to scores list.

# %%
def k_fold():

  scores = []

  (folds, evaluation_indices) = get_folds(attempts, categories, k=4,
                                        tests_probability=0.2, shuffle=True)

  x_evaluation = data[evaluation_indices,:,:]
  y_evaluation = labels[evaluation_indices,:]

  for i in range(len(folds)):
    x_train_fold = np.empty((0,data.shape[1],data.shape[2]), float)
    y_train_fold = np.empty((0,labels.shape[1]), float)
    
    for j in range(i):
      x_train_fold = np.concatenate((x_train_fold, data[folds[j],:,:]), axis=0)
      y_train_fold = np.concatenate((y_train_fold, labels[folds[j],:]), axis=0)

    x_validation_fold = data[folds[i],:,:]
    y_validation_fold = labels[folds[i],:]

    for j in range(i+1, len(folds)):
      x_train_fold = np.concatenate((x_train_fold, data[folds[j],:,:]), axis=0)
      y_train_fold = np.concatenate((y_train_fold, labels[folds[j],:]), axis=0)

    evaluation_model = create_model(x_train_fold, summary=False)

    evaluation_model.compile(loss=categorical_crossentropy,
                            optimizer=Adam(),
                            metrics=[categorical_accuracy])

    evaluation_history = evaluation_model.fit(x_train_fold,
                                              y_train_fold,
                                              epochs=number_of_epochs,
                                              batch_size=number_of_batch_size,
                                              callbacks=[threshold, scheduler],
                                              validation_data=(x_validation_fold, y_validation_fold),
                                              verbose=0)
    
    scores.append(evaluation_model.evaluate(x_evaluation, y_evaluation, verbose=0))

    print(f'\t-Score for fold {i+1}:')
    print(f'\t\t-Evaluation_{evaluation_model.metrics_names[0]} of {scores[i][0]:.2f}')
    print(f'\t\t-Evaluation_{evaluation_model.metrics_names[1]} of {scores[i][1]:.2f}\n')

  return scores

# %% [markdown]
# ### Iterative k-fold results
# Iterate doing k-fild in order to get average evaluation loss and average evaluation accuracy of the model.

# %%
scores = []
iterations = 10
for iter in range(iterations):
  print(f'\nIteracion nº{iter+1}')
  scores += k_fold()
# Out:
# Iteracion nº1
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.46
# 		-Evaluation_categorical_accuracy of 0.89
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.62
# 		-Evaluation_categorical_accuracy of 0.81
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.47
# 		-Evaluation_categorical_accuracy of 0.88
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.56
# 		-Evaluation_categorical_accuracy of 0.88
#
#
# Iteracion nº2
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.54
# 		-Evaluation_categorical_accuracy of 0.84
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.50
# 		-Evaluation_categorical_accuracy of 0.87
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.54
# 		-Evaluation_categorical_accuracy of 0.84
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.59
# 		-Evaluation_categorical_accuracy of 0.87
#
#
# Iteracion nº3
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.51
# 		-Evaluation_categorical_accuracy of 0.86
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.51
# 		-Evaluation_categorical_accuracy of 0.86
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.47
# 		-Evaluation_categorical_accuracy of 0.87
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.52
# 		-Evaluation_categorical_accuracy of 0.88
#
#
# Iteracion nº4
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.37
# 		-Evaluation_categorical_accuracy of 0.92
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.45
# 		-Evaluation_categorical_accuracy of 0.87
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.42
# 		-Evaluation_categorical_accuracy of 0.88
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.38
# 		-Evaluation_categorical_accuracy of 0.89
#
#
# Iteracion nº5
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.37
# 		-Evaluation_categorical_accuracy of 0.94
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.44
# 		-Evaluation_categorical_accuracy of 0.91
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.54
# 		-Evaluation_categorical_accuracy of 0.84
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.41
# 		-Evaluation_categorical_accuracy of 0.89
#
#
# Iteracion nº6
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.44
# 		-Evaluation_categorical_accuracy of 0.89
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.46
# 		-Evaluation_categorical_accuracy of 0.87
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.49
# 		-Evaluation_categorical_accuracy of 0.89
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.43
# 		-Evaluation_categorical_accuracy of 0.89
#
#
# Iteracion nº7
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.48
# 		-Evaluation_categorical_accuracy of 0.89
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.55
# 		-Evaluation_categorical_accuracy of 0.88
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.56
# 		-Evaluation_categorical_accuracy of 0.84
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.64
# 		-Evaluation_categorical_accuracy of 0.87
#
#
# Iteracion nº8
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.43
# 		-Evaluation_categorical_accuracy of 0.90
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.53
# 		-Evaluation_categorical_accuracy of 0.85
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.40
# 		-Evaluation_categorical_accuracy of 0.90
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.57
# 		-Evaluation_categorical_accuracy of 0.85
#
#
# Iteracion nº9
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.64
# 		-Evaluation_categorical_accuracy of 0.83
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.50
# 		-Evaluation_categorical_accuracy of 0.86
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.56
# 		-Evaluation_categorical_accuracy of 0.86
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.61
# 		-Evaluation_categorical_accuracy of 0.86
#
#
# Iteracion nº10
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.49
# 		-Evaluation_categorical_accuracy of 0.88
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.48
# 		-Evaluation_categorical_accuracy of 0.89
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.47
# 		-Evaluation_categorical_accuracy of 0.88
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.50
# 		-Evaluation_categorical_accuracy of 0.86

# %% [markdown]
# ### Boxplot

# %%
import seaborn as sns

loss_scores = [scores[i][0] for  i in range(len(scores))]
accuracy_scores = [scores[i][1] for  i in range(len(scores))]

folds_loss = sum(loss_scores) / len(scores)
folds_accuracy = sum(accuracy_scores) / len(scores) 

sns.set(style="darkgrid")
sns.set(rc={'figure.figsize':(22,16)})

sns.boxplot(x=accuracy_scores, color='skyblue').set(xlabel='Accuracy', ylabel='DeepKnob')
plt.show()

print(f'\nAverage Evaluation Loss: {folds_loss:.3f}')
print(f'Average Evaluation Accuracy: {folds_accuracy:.3f}')
# Out:
# Average Evaluation Loss: 0.498
# Average Evaluation Accuracy: 0.873
