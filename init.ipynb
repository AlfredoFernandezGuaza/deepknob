# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AlfredoFernandezGuaza/deepknob/blob/master/init.ipynb)

# %% [markdown]
# # Download repository
# 1. First remove deepknob folder (so be careful)
# 2. Downlaod repository

# %%
# !rm -r deepknob
# !git clone https://github.com/AlfredoFernandezGuaza/deepknob.git
