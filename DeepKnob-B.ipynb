# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AlfredoFernandezGuaza/deepknob/blob/master/DeepKnob-B.ipynb)

# %% [markdown]
# **Load Repository**

# %%
# !git clone https://github.com/AlfredoFernandezGuaza/deepknob.git

# %% [markdown]
# # DeepKnob
# User identification from data retrieved by sensors using neural networks.

# %%
import tensorflow
from tensorflow import keras

print('Tensorflow version:', keras.__version__)
# Out:
# Tensorflow version: 2.8.0

# %% [markdown]
# ## Dataset
# Contains:
# <ol style="margin-top:0; font-weight:bold">
#     <li>
#         <span>Header:</span>
#         <span style="font-weight:normal"> user_ID, attempt, time(us), accX(g), accY(g), accZ(g), gyrX(o/s), gyrY(o/s), gyrZ(o/s).</span>
#     </li>
#     <li>
#         <span>Data:</span>
#         <span style="font-weight:normal">NOT normalized data.</span>
#     </li>
#     <li>
#         <span>Empty Line:</span>
#         <span style="font-weight:normal">Last line is empty, so we do not use it.</span>
#     </li>
# </ol>
#
# ### Opening the Dataset
# Getting Data from Dataset

# %%
import os
dir = './content/deepknob'
data_dir = os.path.join(dir, 'data')
fname = os.path.join(data_dir, 'final_dataset.csv')

f = open(fname)
raw_data = f.read()
f.close()

lines = raw_data.split('\n')
lines = lines[:-1]
header = lines[0].split(',')
lines = lines[1:]

print('Number of lines:', len(lines))
print("First line:", lines[0])
print("Last line:", lines[-1])
# Out:
# Number of lines: 1405300
# First line: 1,1,0,1.009766,-0.016602,0.016602,0.900763,0.152672,-0.778626
# Last line: 47,20,2478561,1.009277,0.021484,-0.015137,0.748092,0.076336,-0.48855

# %% [markdown]
# ### Process the Raw Data
# Get list of accelerometer and gyroscope floating point values from row data. \
# Each list item is one measure of the accelerometer and gyrocope in the 3 dimensional axis.

# %%
import numpy as np

float_data = np.zeros((len(lines), len(header)))
for i, line in enumerate(lines):
    values = [float(x) for x in line.split(',')]
    float_data[i, :] = values

first_column = 3 
last_column = 9
columns = last_column - first_column
data = float_data[:,first_column:last_column]

# %% [markdown]
# ### One hot encoding of data labels
# Get the labels of each attempt. \
# One attempt is compose by a number of measures. \
# The label is the user_ID who made the attempt. \
# Then vectorize each label as a vector [0,0,...,0,1,0,...,0,0] which length is the number of different users. \
# Number 1 in the one_hot label vector means the user_ID index who made the attempt.

# %%
from tensorflow.keras.utils import to_categorical

measures_per_attempt = 1495
labels = float_data[::measures_per_attempt, 0]

labels = labels-1
labels = labels.astype('int32')

labels = to_categorical(labels)

# %% [markdown]
# ### Reshape data into shape (samples, timesteps, features)
# The number of classes or categories is each label length, which is the same for every label.\
# The number of attempts is the attempts done by each user, which is the same for every user.\
# The new data consists of 3D tensor which shape is the following:
# <ol style="margin-top:0; font-weight:bold">
#     <li>
#         <span>Samples:</span>
#         <span style="font-weight:normal">How many times every user has done an attempt.</span>
#     </li>
#     <li>
#         <span>Timesteps:</span>
#         <span style="font-weight:normal">How many measures are done in an attempt by one user.</span>
#     </li>
#     <li>
#         <span>Features:</span>
#         <span style="font-weight:normal">The different types of measures done each timestep.</span>
#     </li>
# </ol>

# %%
categories = labels.shape[-1]
attempts = int(float_data[-1, 1])

samples = categories * attempts
sensor_readings = len(lines) // samples

data = data.reshape(samples, sensor_readings, columns)

# %% [markdown]
# ### Remove useless data
# Remove the data of measures taken before the contact with the knob.

# %%
batch_begin = 244

data = data[:,batch_begin:,:]

# %% [markdown]
# ### Plot data
# Show data to know where to cut.

# %%
from matplotlib import pyplot as plt

fig, axs = plt.subplots(figsize=(50, 27))
for i, val in enumerate(data):
	axs.plot(data[i,:,:])
axs.grid=True
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Shuffle users and samples
# Randomize users or categories and for each user shuffle their attempts or samples.\
# Return a tuple with training-validation set and test set indices.

# %%
import random

def getIndices(attempts=20,
               categories=47,
               training_probability=0.6,
               validation_probability=0.2,
               shuffle=True):
    
    training_SPC = attempts * int(training_probability * 100) // 100 
    validation_SPC = attempts * int(validation_probability * 100) // 100
    test_SPC = training_SPC + validation_SPC 
    
    train_indices = []
    validation_indices = []
    test_indices = []
    
    random_indices = [i for i in range(attempts)] 

    shuffled_categories = [i for i in range(categories)]
    if shuffle: random.shuffle(shuffled_categories)
    
    for category in shuffled_categories:
        if shuffle: random.shuffle(random_indices)
        for i in random_indices[:training_SPC]: 
            train_indices.append(attempts * category + i)  
        for i in random_indices[training_SPC:test_SPC]:
            validation_indices.append(attempts * category + i) 
        for i in random_indices[test_SPC:]:
            test_indices.append(attempts * category + i) 

    return (train_indices, validation_indices, test_indices)

(train_indices, validate_indices, test_indices) = getIndices(attempts,
                                                             categories,
                                                             0.6,
                                                             0.2,
                                                             shuffle=True)

# %% [markdown]
# ### Split data into training, validation and testing
# Use the shuffled indices to split data in:
# <ol style="margin-top:0; font-weight:bold">
#     <li>
#         <span>Training:</span>
#         <span style="font-weight:normal">Data which will feed the model.</span>
#     </li>
#     <li>
#         <span>Validation:</span>
#         <span style="font-weight:normal">Data use to tune model hyperparameters.</span>
#     </li>
#     <li>
#         <span>Testing:</span>
#         <span style="font-weight:normal">Data which allows the real model performance.</span>
#     </li>
# </ol>

# %%
x_train = data[train_indices,:,:]
y_train = labels[train_indices,:]

x_validate = data[validate_indices,:,:]
y_validate = labels[validate_indices,:]

x_test = data[test_indices,:,:]
y_test = labels[test_indices,:]

# %% [markdown]
# ## Machine learning approach
# Different layers from Keras layers API are used, layers are the basic block ok neural networks in Keras.
# The used Model layers consists:
# <ul style="margin-top:0; font-weight:bold">
#     <li>
#         <span>Normalization:</span>
#         <span style="font-weight:normal">This layer will shift and scale inputs into a distribution centered around 0 with standard deviation 1.</span>
#     </li>
#     <li>
#         <span>LSTM:</span>
#         <span style="font-weight:normal">Long Short-Term Memory layer, an recurrent neural network which takes into acount time series data.</span>
#     </li>
#     <li>
#         <span>Bidirectional:</span>
#         <span style="font-weight:normal">Wrapper of recurrent neural networks which allows to process data forward (from past to future) and backwards (from future to past).</span>
#     </li>
#     <li>
#         <span>Conv1D:</span>
#         <span style="font-weight:normal">The kernel is a window of specified size. Convolutions are the product of doing mathematical operations, mainly scalar products of kernel window size over the input. A filter is a group of kernels, number of kernels is also specified. This layer produce as many convolutions as filters specified. The goal of this layer is learn spatial hierarchies of patterns.</span>
#     </li>
#     <li>
#         <span>MaxPooling1D:</span>
#         <span style="font-weight:normal">The input is divided by a specified integer, in each section produced by the division produce a float with the max value of the section. The purspose of this layer is to down-sample the input, reducing its dimesionality.</span>
#     </li>
#     <li>
#         <span>GloabalMaxPool1D:</span>
#         <span style="font-weight:normal">Down-samples the input representation by taking the maximum value over the time dimension.</span>
#     </li>
#     <li>
#         <span>Flatten:</span>
#         <span style="font-weight:normal">Flattens the input into shape(none, x), where x is the multiplication of input shapes.</span>
#     </li>
#     <li>
#         <span>Dense:</span>
#         <span style="font-weight:normal">Regular densely-connected neural network layer. Each layer neuron recives input from all previos layer neurons. Then a non-linear transformation is done to produce output.</span>
#     </li>
#     <li>
#         <span>Dropout:</span>
#         <span style="font-weight:normal">Sets randomly input units to 0 with a specified frecuency.</span>
#     </li>
# </ul>

# %%
from keras import Input 
from keras.models import Model
from keras.layers.preprocessing.normalization import Normalization
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPooling1D, GlobalMaxPooling1D
from keras.layers.recurrent import LSTM
from keras.layers.wrappers import Bidirectional
from keras.layers.core import Dense
from keras.activations import relu, softmax

def create_model(x_train, summary=True):
  
  # Preprocessing Normalization
  normalizeLayer = Normalization()
  normalizeLayer.adapt(x_train)

  input_tensor = Input(shape=x_train.shape[1:])
  common_input = normalizeLayer(input_tensor)

  # Recurrent and Covolutional Base
  tensor = Conv1D(47, 7, activation=relu)(common_input)
  tensor = MaxPooling1D(5)(tensor)
  tensor = Conv1D(74, 7, activation=relu)(tensor)
  tensor = MaxPooling1D(4)(tensor)
  tensor = Bidirectional(LSTM(27, dropout=0.5, recurrent_dropout=0.2, return_sequences=True))(tensor)
  tensor = Conv1D(47, 7, activation=relu)(tensor)
  tensor = MaxPooling1D(3)(tensor)
  tensor = GlobalMaxPooling1D()(tensor)
  
  # Classifier
  output_tensor = Dense(47, activation=softmax)(tensor)

  model = Model(input_tensor, output_tensor)

  if summary: model.summary()

  return model

model = create_model(x_train)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1251, 6)]         0
#
#  normalization (Normalizatio  (None, 1251, 6)          13
#  n)
#
#  conv1d (Conv1D)             (None, 1245, 47)          2021
#
#  max_pooling1d (MaxPooling1D  (None, 249, 47)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 243, 74)           24420
#
#  max_pooling1d_1 (MaxPooling  (None, 60, 74)           0
#  1D)
#
#  bidirectional (Bidirectiona  (None, 60, 54)           22032
#  l)
#
#  conv1d_2 (Conv1D)           (None, 54, 47)            17813
#
#  max_pooling1d_2 (MaxPooling  (None, 18, 47)           0
#  1D)
#
#  global_max_pooling1d (Globa  (None, 47)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 47)                2256
#
# =================================================================
# Total params: 68,555
# Trainable params: 68,542
# Non-trainable params: 13
# _________________________________________________________________

# %% [markdown]
# ### Model callbacks
# The model stops training if two conditions are met:
#
# *   Number of epochs with no improvement is greater than an specified variable.
# *   Training loss is less than 0.1 or validation accuracy is greater than threashold.

# %%
from keras.callbacks import Callback, ModelCheckpoint, LearningRateScheduler 

class ThresholdCallback(Callback):
    def __init__(self, threshold, max_loss=0.1, patience=0):
        super(ThresholdCallback, self).__init__()
        self.threshold = threshold
        self.max_loss = max_loss
        self.patience = patience
        
        self.best_weights = None

    def on_train_begin(self, logs=None):
        self.wait = 0
        self.best = np.Inf

    def on_epoch_end(self, epoch, logs=None): 
        val_accuracy = logs.get('val_categorical_accuracy')
        current = logs.get('loss')
        
        if np.less(current, self.best):
            self.best = current
            self.wait = 0
            self.best_weights = self.model.get_weights()
        else:
            self.wait += 1
            is_patience_end = self.wait >= self.patience
            is_out_of_threshold = val_accuracy > self.threshold
            is_less_than_max_loss = current < self.max_loss
            stop = is_patience_end and (is_out_of_threshold or is_less_than_max_loss)
            if stop:
                self.model.stop_training = True
                self.model.set_weights(self.best_weights)
        

models_dir = os.path.join(drive_dir, 'models')
model_path = os.path.join(models_dir, 'deepKnob-B.h5')

threshold = ThresholdCallback(threshold=0.9, patience=1)

checkpoint = ModelCheckpoint(filepath=model_path,
                             monitor='val_categorical_accuracy',
                             save_best_only=True)

def scheduler(epoch, lr):
  if epoch in {25, 35, 50}:
    return lr / 2

  return lr

scheduler = LearningRateScheduler(scheduler)

# %% [markdown]
# ### Compile and fit the model
# Due to DeepKnob is a classification so problem *categorical_crossentropy* is used.

# %%
from tensorflow.keras.optimizers import Adam
from keras.losses import categorical_crossentropy
from keras.metrics import categorical_accuracy

number_of_epochs = 100
number_of_batch_size = 32

model.compile(loss=categorical_crossentropy,
              optimizer=Adam(),
              metrics=[categorical_accuracy])

history = model.fit(x_train,
                    y_train,
                    epochs=number_of_epochs,
                    batch_size=number_of_batch_size,
                    callbacks=[threshold, checkpoint, scheduler],
                    validation_data=(x_validate, y_validate))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 9s 204ms/step - loss: 3.8784 - categorical_accuracy: 0.0177 - val_loss: 3.8353 - val_categorical_accuracy: 0.0319 - lr: 0.0010
# Epoch 2/100
# 18/18 [==============================] - 3s 157ms/step - loss: 3.8451 - categorical_accuracy: 0.0266 - val_loss: 3.8155 - val_categorical_accuracy: 0.0372 - lr: 0.0010
# Epoch 3/100
# 18/18 [==============================] - 3s 158ms/step - loss: 3.8054 - categorical_accuracy: 0.0372 - val_loss: 3.7495 - val_categorical_accuracy: 0.0904 - lr: 0.0010
# Epoch 4/100
# 18/18 [==============================] - 3s 157ms/step - loss: 3.7545 - categorical_accuracy: 0.0479 - val_loss: 3.6466 - val_categorical_accuracy: 0.0957 - lr: 0.0010
# Epoch 5/100
# 18/18 [==============================] - 3s 159ms/step - loss: 3.6350 - categorical_accuracy: 0.0922 - val_loss: 3.4303 - val_categorical_accuracy: 0.1011 - lr: 0.0010
# Epoch 6/100
# 18/18 [==============================] - 3s 155ms/step - loss: 3.3762 - categorical_accuracy: 0.1418 - val_loss: 3.0242 - val_categorical_accuracy: 0.2021 - lr: 0.0010
# Epoch 7/100
# 18/18 [==============================] - 3s 187ms/step - loss: 3.0131 - categorical_accuracy: 0.1720 - val_loss: 2.5583 - val_categorical_accuracy: 0.3138 - lr: 0.0010
# Epoch 8/100
# 18/18 [==============================] - 5s 299ms/step - loss: 2.5655 - categorical_accuracy: 0.2766 - val_loss: 2.0964 - val_categorical_accuracy: 0.4734 - lr: 0.0010
# Epoch 9/100
# 18/18 [==============================] - 4s 192ms/step - loss: 2.1471 - categorical_accuracy: 0.4202 - val_loss: 1.6795 - val_categorical_accuracy: 0.5479 - lr: 0.0010
# Epoch 10/100
# 18/18 [==============================] - 3s 157ms/step - loss: 1.7487 - categorical_accuracy: 0.5301 - val_loss: 1.4449 - val_categorical_accuracy: 0.5585 - lr: 0.0010
# Epoch 11/100
# 18/18 [==============================] - 3s 159ms/step - loss: 1.4703 - categorical_accuracy: 0.6135 - val_loss: 1.2523 - val_categorical_accuracy: 0.6543 - lr: 0.0010
# Epoch 12/100
# 18/18 [==============================] - 3s 159ms/step - loss: 1.2536 - categorical_accuracy: 0.6596 - val_loss: 1.2649 - val_categorical_accuracy: 0.6596 - lr: 0.0010
# Epoch 13/100
# 18/18 [==============================] - 3s 157ms/step - loss: 1.1369 - categorical_accuracy: 0.6950 - val_loss: 1.0644 - val_categorical_accuracy: 0.6649 - lr: 0.0010
# Epoch 14/100
# 18/18 [==============================] - 3s 156ms/step - loss: 0.9809 - categorical_accuracy: 0.7287 - val_loss: 0.9577 - val_categorical_accuracy: 0.7340 - lr: 0.0010
# Epoch 15/100
# 18/18 [==============================] - 4s 217ms/step - loss: 0.9074 - categorical_accuracy: 0.7589 - val_loss: 0.8738 - val_categorical_accuracy: 0.7021 - lr: 0.0010
# Epoch 16/100
# 18/18 [==============================] - 3s 154ms/step - loss: 0.8403 - categorical_accuracy: 0.7642 - val_loss: 0.8238 - val_categorical_accuracy: 0.7128 - lr: 0.0010
# Epoch 17/100
# 18/18 [==============================] - 3s 157ms/step - loss: 0.7260 - categorical_accuracy: 0.7819 - val_loss: 0.8043 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 18/100
# 18/18 [==============================] - 3s 154ms/step - loss: 0.7026 - categorical_accuracy: 0.7872 - val_loss: 0.7707 - val_categorical_accuracy: 0.7447 - lr: 0.0010
# Epoch 19/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.6227 - categorical_accuracy: 0.8316 - val_loss: 0.7510 - val_categorical_accuracy: 0.7766 - lr: 0.0010
# Epoch 20/100
# 18/18 [==============================] - 3s 155ms/step - loss: 0.5816 - categorical_accuracy: 0.8298 - val_loss: 0.7579 - val_categorical_accuracy: 0.7287 - lr: 0.0010
# Epoch 21/100
# 18/18 [==============================] - 3s 157ms/step - loss: 0.5259 - categorical_accuracy: 0.8652 - val_loss: 0.6720 - val_categorical_accuracy: 0.7979 - lr: 0.0010
# Epoch 22/100
# 18/18 [==============================] - 3s 157ms/step - loss: 0.4831 - categorical_accuracy: 0.8706 - val_loss: 0.6973 - val_categorical_accuracy: 0.8085 - lr: 0.0010
# Epoch 23/100
# 18/18 [==============================] - 3s 153ms/step - loss: 0.4805 - categorical_accuracy: 0.8582 - val_loss: 0.6663 - val_categorical_accuracy: 0.7979 - lr: 0.0010
# Epoch 24/100
# 18/18 [==============================] - 3s 153ms/step - loss: 0.4104 - categorical_accuracy: 0.8989 - val_loss: 0.6935 - val_categorical_accuracy: 0.7766 - lr: 0.0010
# Epoch 25/100
# 18/18 [==============================] - 3s 156ms/step - loss: 0.3764 - categorical_accuracy: 0.9043 - val_loss: 0.6523 - val_categorical_accuracy: 0.7979 - lr: 0.0010
# Epoch 26/100
# 18/18 [==============================] - 5s 271ms/step - loss: 0.3352 - categorical_accuracy: 0.9273 - val_loss: 0.6139 - val_categorical_accuracy: 0.8138 - lr: 5.0000e-04
# Epoch 27/100
# 18/18 [==============================] - 3s 153ms/step - loss: 0.3421 - categorical_accuracy: 0.9202 - val_loss: 0.5897 - val_categorical_accuracy: 0.8138 - lr: 5.0000e-04
# Epoch 28/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.3186 - categorical_accuracy: 0.9397 - val_loss: 0.6110 - val_categorical_accuracy: 0.8245 - lr: 5.0000e-04
# Epoch 29/100
# 18/18 [==============================] - 3s 157ms/step - loss: 0.3030 - categorical_accuracy: 0.9344 - val_loss: 0.5635 - val_categorical_accuracy: 0.8085 - lr: 5.0000e-04
# Epoch 30/100
# 18/18 [==============================] - 3s 159ms/step - loss: 0.2740 - categorical_accuracy: 0.9433 - val_loss: 0.5864 - val_categorical_accuracy: 0.8085 - lr: 5.0000e-04
# Epoch 31/100
# 18/18 [==============================] - 3s 159ms/step - loss: 0.2564 - categorical_accuracy: 0.9557 - val_loss: 0.5559 - val_categorical_accuracy: 0.8191 - lr: 5.0000e-04
# Epoch 32/100
# 18/18 [==============================] - 3s 156ms/step - loss: 0.2464 - categorical_accuracy: 0.9574 - val_loss: 0.5681 - val_categorical_accuracy: 0.8138 - lr: 5.0000e-04
# Epoch 33/100
# 18/18 [==============================] - 3s 156ms/step - loss: 0.2428 - categorical_accuracy: 0.9468 - val_loss: 0.5746 - val_categorical_accuracy: 0.8245 - lr: 5.0000e-04
# Epoch 34/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.2115 - categorical_accuracy: 0.9645 - val_loss: 0.5693 - val_categorical_accuracy: 0.8085 - lr: 5.0000e-04
# Epoch 35/100
# 18/18 [==============================] - 3s 159ms/step - loss: 0.2134 - categorical_accuracy: 0.9574 - val_loss: 0.5562 - val_categorical_accuracy: 0.8191 - lr: 5.0000e-04
# Epoch 36/100
# 18/18 [==============================] - 3s 194ms/step - loss: 0.2106 - categorical_accuracy: 0.9574 - val_loss: 0.5314 - val_categorical_accuracy: 0.8298 - lr: 2.5000e-04
# Epoch 37/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.2101 - categorical_accuracy: 0.9574 - val_loss: 0.5603 - val_categorical_accuracy: 0.8085 - lr: 2.5000e-04
# Epoch 38/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.1971 - categorical_accuracy: 0.9663 - val_loss: 0.5390 - val_categorical_accuracy: 0.8138 - lr: 2.5000e-04
# Epoch 39/100
# 18/18 [==============================] - 3s 157ms/step - loss: 0.2052 - categorical_accuracy: 0.9663 - val_loss: 0.5341 - val_categorical_accuracy: 0.8191 - lr: 2.5000e-04
# Epoch 40/100
# 18/18 [==============================] - 3s 159ms/step - loss: 0.1805 - categorical_accuracy: 0.9787 - val_loss: 0.5543 - val_categorical_accuracy: 0.8191 - lr: 2.5000e-04
# Epoch 41/100
# 18/18 [==============================] - 3s 157ms/step - loss: 0.2050 - categorical_accuracy: 0.9592 - val_loss: 0.5343 - val_categorical_accuracy: 0.8298 - lr: 2.5000e-04
# Epoch 42/100
# 18/18 [==============================] - 3s 157ms/step - loss: 0.1766 - categorical_accuracy: 0.9699 - val_loss: 0.5653 - val_categorical_accuracy: 0.8138 - lr: 2.5000e-04
# Epoch 43/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.1717 - categorical_accuracy: 0.9734 - val_loss: 0.5411 - val_categorical_accuracy: 0.8138 - lr: 2.5000e-04
# Epoch 44/100
# 18/18 [==============================] - 3s 157ms/step - loss: 0.1766 - categorical_accuracy: 0.9770 - val_loss: 0.5462 - val_categorical_accuracy: 0.8245 - lr: 2.5000e-04
# Epoch 45/100
# 18/18 [==============================] - 3s 157ms/step - loss: 0.1697 - categorical_accuracy: 0.9716 - val_loss: 0.5381 - val_categorical_accuracy: 0.8191 - lr: 2.5000e-04
# Epoch 46/100
# 18/18 [==============================] - 3s 189ms/step - loss: 0.1586 - categorical_accuracy: 0.9805 - val_loss: 0.5433 - val_categorical_accuracy: 0.8351 - lr: 2.5000e-04
# Epoch 47/100
# 18/18 [==============================] - 3s 160ms/step - loss: 0.1634 - categorical_accuracy: 0.9734 - val_loss: 0.5350 - val_categorical_accuracy: 0.8138 - lr: 2.5000e-04
# Epoch 48/100
# 18/18 [==============================] - 3s 154ms/step - loss: 0.1487 - categorical_accuracy: 0.9787 - val_loss: 0.5528 - val_categorical_accuracy: 0.8298 - lr: 2.5000e-04
# Epoch 49/100
# 18/18 [==============================] - 3s 159ms/step - loss: 0.1683 - categorical_accuracy: 0.9681 - val_loss: 0.5434 - val_categorical_accuracy: 0.8298 - lr: 2.5000e-04
# Epoch 50/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.1589 - categorical_accuracy: 0.9716 - val_loss: 0.5382 - val_categorical_accuracy: 0.8351 - lr: 2.5000e-04
# Epoch 51/100
# 18/18 [==============================] - 3s 159ms/step - loss: 0.1625 - categorical_accuracy: 0.9681 - val_loss: 0.5264 - val_categorical_accuracy: 0.8191 - lr: 1.2500e-04
# Epoch 52/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.1560 - categorical_accuracy: 0.9823 - val_loss: 0.5311 - val_categorical_accuracy: 0.8138 - lr: 1.2500e-04
# Epoch 53/100
# 18/18 [==============================] - 3s 159ms/step - loss: 0.1387 - categorical_accuracy: 0.9823 - val_loss: 0.5357 - val_categorical_accuracy: 0.8245 - lr: 1.2500e-04
# Epoch 54/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.1477 - categorical_accuracy: 0.9823 - val_loss: 0.5264 - val_categorical_accuracy: 0.8351 - lr: 1.2500e-04
# Epoch 55/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.1355 - categorical_accuracy: 0.9787 - val_loss: 0.5267 - val_categorical_accuracy: 0.8191 - lr: 1.2500e-04
# Epoch 56/100
# 18/18 [==============================] - 3s 159ms/step - loss: 0.1395 - categorical_accuracy: 0.9840 - val_loss: 0.5311 - val_categorical_accuracy: 0.8191 - lr: 1.2500e-04
# Epoch 57/100
# 18/18 [==============================] - 3s 157ms/step - loss: 0.1422 - categorical_accuracy: 0.9787 - val_loss: 0.5279 - val_categorical_accuracy: 0.8245 - lr: 1.2500e-04
# Epoch 58/100
# 18/18 [==============================] - 3s 156ms/step - loss: 0.1280 - categorical_accuracy: 0.9805 - val_loss: 0.5266 - val_categorical_accuracy: 0.8138 - lr: 1.2500e-04
# Epoch 59/100
# 18/18 [==============================] - 3s 154ms/step - loss: 0.1269 - categorical_accuracy: 0.9894 - val_loss: 0.5256 - val_categorical_accuracy: 0.8245 - lr: 1.2500e-04
# Epoch 60/100
# 18/18 [==============================] - 3s 157ms/step - loss: 0.1243 - categorical_accuracy: 0.9840 - val_loss: 0.5418 - val_categorical_accuracy: 0.8138 - lr: 1.2500e-04
# Epoch 61/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.1301 - categorical_accuracy: 0.9876 - val_loss: 0.5432 - val_categorical_accuracy: 0.8298 - lr: 1.2500e-04
# Epoch 62/100
# 18/18 [==============================] - 3s 183ms/step - loss: 0.1401 - categorical_accuracy: 0.9787 - val_loss: 0.5411 - val_categorical_accuracy: 0.8457 - lr: 1.2500e-04
# Epoch 63/100
# 18/18 [==============================] - 3s 163ms/step - loss: 0.1411 - categorical_accuracy: 0.9823 - val_loss: 0.5241 - val_categorical_accuracy: 0.8245 - lr: 1.2500e-04
# Epoch 64/100
# 18/18 [==============================] - 3s 160ms/step - loss: 0.1244 - categorical_accuracy: 0.9840 - val_loss: 0.5315 - val_categorical_accuracy: 0.8191 - lr: 1.2500e-04
# Epoch 65/100
# 18/18 [==============================] - 3s 159ms/step - loss: 0.1273 - categorical_accuracy: 0.9805 - val_loss: 0.5389 - val_categorical_accuracy: 0.8351 - lr: 1.2500e-04
# Epoch 66/100
# 18/18 [==============================] - 3s 159ms/step - loss: 0.1405 - categorical_accuracy: 0.9734 - val_loss: 0.5202 - val_categorical_accuracy: 0.8245 - lr: 1.2500e-04
# Epoch 67/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.1269 - categorical_accuracy: 0.9823 - val_loss: 0.5341 - val_categorical_accuracy: 0.8191 - lr: 1.2500e-04
# Epoch 68/100
# 18/18 [==============================] - 3s 159ms/step - loss: 0.1274 - categorical_accuracy: 0.9823 - val_loss: 0.5219 - val_categorical_accuracy: 0.8138 - lr: 1.2500e-04
# Epoch 69/100
# 18/18 [==============================] - 3s 157ms/step - loss: 0.1206 - categorical_accuracy: 0.9894 - val_loss: 0.5221 - val_categorical_accuracy: 0.8245 - lr: 1.2500e-04
# Epoch 70/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.1308 - categorical_accuracy: 0.9823 - val_loss: 0.5178 - val_categorical_accuracy: 0.8351 - lr: 1.2500e-04
# Epoch 71/100
# 18/18 [==============================] - 3s 157ms/step - loss: 0.1268 - categorical_accuracy: 0.9805 - val_loss: 0.5325 - val_categorical_accuracy: 0.8191 - lr: 1.2500e-04
# Epoch 72/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.1386 - categorical_accuracy: 0.9770 - val_loss: 0.5174 - val_categorical_accuracy: 0.8245 - lr: 1.2500e-04
# Epoch 73/100
# 18/18 [==============================] - 3s 160ms/step - loss: 0.1101 - categorical_accuracy: 0.9840 - val_loss: 0.5298 - val_categorical_accuracy: 0.8298 - lr: 1.2500e-04
# Epoch 74/100
# 18/18 [==============================] - 3s 159ms/step - loss: 0.1188 - categorical_accuracy: 0.9929 - val_loss: 0.5188 - val_categorical_accuracy: 0.8298 - lr: 1.2500e-04
# Epoch 75/100
# 18/18 [==============================] - 3s 160ms/step - loss: 0.1262 - categorical_accuracy: 0.9840 - val_loss: 0.5103 - val_categorical_accuracy: 0.8298 - lr: 1.2500e-04
# Epoch 76/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.1147 - categorical_accuracy: 0.9840 - val_loss: 0.5091 - val_categorical_accuracy: 0.8351 - lr: 1.2500e-04
# Epoch 77/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.1208 - categorical_accuracy: 0.9823 - val_loss: 0.5094 - val_categorical_accuracy: 0.8404 - lr: 1.2500e-04
# Epoch 78/100
# 18/18 [==============================] - 3s 159ms/step - loss: 0.1069 - categorical_accuracy: 0.9858 - val_loss: 0.5149 - val_categorical_accuracy: 0.8404 - lr: 1.2500e-04
# Epoch 79/100
# 18/18 [==============================] - 3s 160ms/step - loss: 0.1107 - categorical_accuracy: 0.9840 - val_loss: 0.5281 - val_categorical_accuracy: 0.8351 - lr: 1.2500e-04
# Epoch 80/100
# 18/18 [==============================] - 3s 160ms/step - loss: 0.1095 - categorical_accuracy: 0.9894 - val_loss: 0.5252 - val_categorical_accuracy: 0.8351 - lr: 1.2500e-04
# Epoch 81/100
# 18/18 [==============================] - 3s 160ms/step - loss: 0.1112 - categorical_accuracy: 0.9911 - val_loss: 0.5167 - val_categorical_accuracy: 0.8351 - lr: 1.2500e-04
# Epoch 82/100
# 18/18 [==============================] - 3s 159ms/step - loss: 0.1126 - categorical_accuracy: 0.9840 - val_loss: 0.5125 - val_categorical_accuracy: 0.8245 - lr: 1.2500e-04
# Epoch 83/100
# 18/18 [==============================] - 3s 158ms/step - loss: 0.0998 - categorical_accuracy: 0.9947 - val_loss: 0.5064 - val_categorical_accuracy: 0.8298 - lr: 1.2500e-04
# Epoch 84/100
# 18/18 [==============================] - 3s 159ms/step - loss: 0.1148 - categorical_accuracy: 0.9858 - val_loss: 0.5078 - val_categorical_accuracy: 0.8245 - lr: 1.2500e-04
# Epoch 85/100
# 18/18 [==============================] - 3s 159ms/step - loss: 0.0958 - categorical_accuracy: 0.9911 - val_loss: 0.5336 - val_categorical_accuracy: 0.8404 - lr: 1.2500e-04
# Epoch 86/100
# 18/18 [==============================] - 3s 157ms/step - loss: 0.1042 - categorical_accuracy: 0.9876 - val_loss: 0.5032 - val_categorical_accuracy: 0.8138 - lr: 1.2500e-04
# Epoch 87/100
# 18/18 [==============================] - 3s 156ms/step - loss: 0.1059 - categorical_accuracy: 0.9858 - val_loss: 0.5172 - val_categorical_accuracy: 0.8245 - lr: 1.2500e-04
# Epoch 88/100
# 18/18 [==============================] - 3s 156ms/step - loss: 0.0956 - categorical_accuracy: 0.9929 - val_loss: 0.5225 - val_categorical_accuracy: 0.8245 - lr: 1.2500e-04
# Epoch 89/100
# 18/18 [==============================] - 3s 155ms/step - loss: 0.1047 - categorical_accuracy: 0.9911 - val_loss: 0.5002 - val_categorical_accuracy: 0.8404 - lr: 1.2500e-04
# Epoch 90/100
# 18/18 [==============================] - 3s 176ms/step - loss: 0.0998 - categorical_accuracy: 0.9858 - val_loss: 0.4951 - val_categorical_accuracy: 0.8511 - lr: 1.2500e-04

# %% [markdown]
# ### A way to get a smoth curve
# Each point from a list is treated in order to show a smoth curve if it is plotted in a graph.

# %%
def smooth_curve(points, factor=0.9):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# %% [markdown]
# ### Model loss and validation loss
# If loss ≈ validation loss, there is no overfitting neither underfitting.\
# If loss < validation loss, there is overfitting.\
# If loss > validation loss, there is underfitting.

# %%
loss = smooth_curve(history.history['loss'])
val_loss = smooth_curve(history.history['val_loss'])

epochs = range(len(loss))

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ### Model accuracy and validation accuracy
# Accuracy shows the probability of identify the right user.

# %%
val_accur = smooth_curve(history.history['val_categorical_accuracy'])
accur = smooth_curve(history.history['categorical_accuracy'])

plt.figure()

plt.plot(epochs, accur, 'ro', label='Training acc')
plt.plot(epochs, val_accur, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ## Evaluation on test data
# Shows how well the model generalize

# %%
model = keras.models.load_model(model_path)

model.evaluate(x_test, y_test)
# Out:
# 6/6 [==============================] - 1s 28ms/step - loss: 0.3692 - categorical_accuracy: 0.8883
# [0.3692009747028351, 0.8882978558540344]

# %% [markdown]
# ### Confusion Matrix
# Is displayed a matrix which shows if each attempt has been right or if it is being recognized by other user. \
# If the attempt is inside the diagonal, the attempt was rigth.

# %%
from sklearn.metrics import ConfusionMatrixDisplay

y_predictions = model.predict(x_test)

fig, ax = plt.subplots(figsize=(20, 20))

confusion_matrix = ConfusionMatrixDisplay.from_predictions(
    tensorflow.argmax(y_test, 1),
    tensorflow.argmax(y_predictions,1),
    display_labels=[i for i in range(47)],
    cmap=plt.cm.Blues,
    normalize=None,
    ax=ax
)
confusion_matrix.ax_.set_title("Normalized confusion matrix")

plt.show()

# %% [markdown]
# ### More evaluation metrics
# Shows for each user id:
#
# *   True positive rate.
# *   True negative rate.
# *   False positive rate.
# *   False negative rate.
# *   Overall acurracy.

# %%
FP = confusion_matrix.confusion_matrix.sum(axis=0) - np.diag(confusion_matrix.confusion_matrix)  
FN = confusion_matrix.confusion_matrix.sum(axis=1) - np.diag(confusion_matrix.confusion_matrix)
TP = np.diag(confusion_matrix.confusion_matrix)
TN = confusion_matrix.confusion_matrix.sum() - (FP + FN + TP)

matrix = np.zeros((47,5))
print('User_Id'+'\t\t '+'TPR'+'\t '+'TNR'+'\t '+'FPR'+'\t '+'FNR'+'\t '+'ACC')
print('-----------------------------------------------------')
for i in range(47):
    # Sensitivity, hit rate, recall, or true positive rate
    TPR = TP[i]/(TP[i]+FN[i])
    matrix[i,0] = TPR
    # Specificity or true negative rate
    TNR = TN[i]/(TN[i]+FP[i])
    matrix[i,1] = TNR
    # Fall out or false positive rate
    FPR = FP[i]/(FP[i]+TN[i])
    matrix[i,2] = FPR
    # False negative rate
    FNR = FN[i]/(TP[i]+FN[i])
    matrix[i,3] = FNR

    # Overall accuracy
    ACC = (TP[i]+TN[i])/(TP[i]+FP[i]+FN[i]+TN[i])
    matrix[i,4] = ACC
    print('user_id',i , '\t', *[str(round(i,2))+'\t' for i in matrix[i,:]])
# Out:
# User_Id		 TPR	 TNR	 FPR	 FNR	 ACC
# -----------------------------------------------------
# user_id 0 	 0.5	 1.0	 0.0	 0.5	 0.99
# user_id 1 	 0.75	 0.99	 0.01	 0.25	 0.99
# user_id 2 	 0.75	 0.99	 0.01	 0.25	 0.98
# user_id 3 	 0.75	 1.0	 0.0	 0.25	 0.99
# user_id 4 	 0.75	 0.99	 0.01	 0.25	 0.99
# user_id 5 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 6 	 0.75	 1.0	 0.0	 0.25	 0.99
# user_id 7 	 0.75	 1.0	 0.0	 0.25	 0.99
# user_id 8 	 1.0	 0.99	 0.01	 0.0	 0.99
# user_id 9 	 1.0	 0.99	 0.01	 0.0	 0.99
# user_id 10 	 1.0	 0.99	 0.01	 0.0	 0.99
# user_id 11 	 0.5	 0.99	 0.01	 0.5	 0.98
# user_id 12 	 1.0	 0.99	 0.01	 0.0	 0.99
# user_id 13 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 14 	 0.75	 0.99	 0.01	 0.25	 0.98
# user_id 15 	 0.5	 1.0	 0.0	 0.5	 0.99
# user_id 16 	 0.5	 1.0	 0.0	 0.5	 0.99
# user_id 17 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 18 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 19 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 20 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 21 	 1.0	 0.99	 0.01	 0.0	 0.99
# user_id 22 	 0.75	 0.99	 0.01	 0.25	 0.98
# user_id 23 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 24 	 1.0	 0.99	 0.01	 0.0	 0.99
# user_id 25 	 1.0	 0.99	 0.01	 0.0	 0.99
# user_id 26 	 0.75	 0.99	 0.01	 0.25	 0.99
# user_id 27 	 0.75	 1.0	 0.0	 0.25	 0.99
# user_id 28 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 29 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 30 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 31 	 1.0	 0.99	 0.01	 0.0	 0.99
# user_id 32 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 33 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 34 	 0.75	 1.0	 0.0	 0.25	 0.99
# user_id 35 	 0.75	 1.0	 0.0	 0.25	 0.99
# user_id 36 	 1.0	 0.99	 0.01	 0.0	 0.99
# user_id 37 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 38 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 39 	 0.75	 0.99	 0.01	 0.25	 0.99
# user_id 40 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 41 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 42 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 43 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 44 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 45 	 1.0	 1.0	 0.0	 0.0	 1.0
# user_id 46 	 1.0	 1.0	 0.0	 0.0	 1.0

# %% [markdown]
# ## Iterative k-fold evaluation
# 1.   Shuffle users and samples.
# 2.   Split data into two subsets (folds, tests). The folds subset contains k subsets.
# 3.   Use k-1 subsets to train the model and 1 subset for validation, evaluating on tests.
# 4.   Repeat k times step 3 using a diferent validation subset.
# 5.   Go to step 1 and repeat the process as many times as you want.
# 6.   Get average results.

# %% [markdown]
# ### Split data into folds and tests
# Shuffle data and then create balance subsets.

# %%
def get_folds(attempts=20, categories=47, k=4,
              tests_probability=0.2, shuffle=True):
    
    test_attempts = attempts * int(tests_probability * 100) // 100 
    training_and_validation_attempts = attempts - test_attempts 
    
    step = training_and_validation_attempts // k

    folds = [ [] for _ in range(k) ]
    test_indices = []
    
    shuffled_attempts = [i for i in range(attempts)] 

    shuffled_categories = [i for i in range(categories)]
    if shuffle: random.shuffle(shuffled_categories)
    
    for category in shuffled_categories:
        if shuffle: random.shuffle(shuffled_attempts)
        fold_index = 0
        for j in range(0, training_and_validation_attempts, step):
          for i in shuffled_attempts[j:j+step]: 
            folds[fold_index].append(attempts * category + i)  
          fold_index += 1
        for i in shuffled_attempts[training_and_validation_attempts:]:
            test_indices.append(attempts * category + i) 

    return (folds, test_indices)

# %% [markdown]
# ### K-fold
# Add validation loss and validation accuracy to scores list.

# %%
def k_fold():

  scores = []

  (folds, evaluation_indices) = get_folds(attempts, categories, k=4,
                                        tests_probability=0.2, shuffle=True)

  x_evaluation = data[evaluation_indices,:,:]
  y_evaluation = labels[evaluation_indices,:]

  for i in range(len(folds)):
    x_train_fold = np.empty((0,data.shape[1],data.shape[2]), float)
    y_train_fold = np.empty((0,labels.shape[1]), float)
    
    for j in range(i):
      x_train_fold = np.concatenate((x_train_fold, data[folds[j],:,:]), axis=0)
      y_train_fold = np.concatenate((y_train_fold, labels[folds[j],:]), axis=0)

    x_validation_fold = data[folds[i],:,:]
    y_validation_fold = labels[folds[i],:]

    for j in range(i+1, len(folds)):
      x_train_fold = np.concatenate((x_train_fold, data[folds[j],:,:]), axis=0)
      y_train_fold = np.concatenate((y_train_fold, labels[folds[j],:]), axis=0)

    evaluation_model = create_model(x_train_fold, summary=False)

    evaluation_model.compile(loss=categorical_crossentropy,
                            optimizer=Adam(),
                            metrics=[categorical_accuracy])

    evaluation_history = evaluation_model.fit(x_train_fold,
                                              y_train_fold,
                                              epochs=number_of_epochs,
                                              batch_size=number_of_batch_size,
                                              callbacks=[threshold, scheduler],
                                              validation_data=(x_validation_fold, y_validation_fold),
                                              verbose=0)
    
    scores.append(evaluation_model.evaluate(x_evaluation, y_evaluation, verbose=0))

    print(f'\t-Score for fold {i+1}:')
    print(f'\t\t-Evaluation_{evaluation_model.metrics_names[0]} of {scores[i][0]:.2f}')
    print(f'\t\t-Evaluation_{evaluation_model.metrics_names[1]} of {scores[i][1]:.2f}\n')

  return scores

# %% [markdown]
# ### Iterative k-fold results
# Iterate doing k-fild in order to get average evaluation loss and average evaluation accuracy of the model.

# %%
scores = []
iterations = 10
for iter in range(iterations):
  print(f'\nIteracion nº{iter+1}')
  scores += k_fold()
# Out:
# Iteracion nº1
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.32
# 		-Evaluation_categorical_accuracy of 0.90
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.39
# 		-Evaluation_categorical_accuracy of 0.87
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.45
# 		-Evaluation_categorical_accuracy of 0.87
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.41
# 		-Evaluation_categorical_accuracy of 0.87
#
#
# Iteracion nº2
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.52
# 		-Evaluation_categorical_accuracy of 0.85
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.45
# 		-Evaluation_categorical_accuracy of 0.87
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.56
# 		-Evaluation_categorical_accuracy of 0.86
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.74
# 		-Evaluation_categorical_accuracy of 0.84
#
#
# Iteracion nº3
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.44
# 		-Evaluation_categorical_accuracy of 0.87
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.58
# 		-Evaluation_categorical_accuracy of 0.82
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.41
# 		-Evaluation_categorical_accuracy of 0.88
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.55
# 		-Evaluation_categorical_accuracy of 0.82
#
#
# Iteracion nº4
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.57
# 		-Evaluation_categorical_accuracy of 0.83
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.49
# 		-Evaluation_categorical_accuracy of 0.86
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.69
# 		-Evaluation_categorical_accuracy of 0.82
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.67
# 		-Evaluation_categorical_accuracy of 0.79
#
#
# Iteracion nº5
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.56
# 		-Evaluation_categorical_accuracy of 0.85
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.77
# 		-Evaluation_categorical_accuracy of 0.84
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.67
# 		-Evaluation_categorical_accuracy of 0.81
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.51
# 		-Evaluation_categorical_accuracy of 0.83
#
#
# Iteracion nº6
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.42
# 		-Evaluation_categorical_accuracy of 0.85
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.49
# 		-Evaluation_categorical_accuracy of 0.83
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.46
# 		-Evaluation_categorical_accuracy of 0.84
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.45
# 		-Evaluation_categorical_accuracy of 0.84
#
#
# Iteracion nº7
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.46
# 		-Evaluation_categorical_accuracy of 0.85
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.65
# 		-Evaluation_categorical_accuracy of 0.83
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.46
# 		-Evaluation_categorical_accuracy of 0.86
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.48
# 		-Evaluation_categorical_accuracy of 0.83
#
#
# Iteracion nº8
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.42
# 		-Evaluation_categorical_accuracy of 0.85
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.35
# 		-Evaluation_categorical_accuracy of 0.90
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.43
# 		-Evaluation_categorical_accuracy of 0.87
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.49
# 		-Evaluation_categorical_accuracy of 0.88
#
#
# Iteracion nº9
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.55
# 		-Evaluation_categorical_accuracy of 0.86
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.54
# 		-Evaluation_categorical_accuracy of 0.85
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.46
# 		-Evaluation_categorical_accuracy of 0.87
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.40
# 		-Evaluation_categorical_accuracy of 0.86
#
#
# Iteracion nº10
# 	-Score for fold 1:
# 		-Evaluation_loss of 0.45
# 		-Evaluation_categorical_accuracy of 0.87
#
# 	-Score for fold 2:
# 		-Evaluation_loss of 0.42
# 		-Evaluation_categorical_accuracy of 0.90
#
# 	-Score for fold 3:
# 		-Evaluation_loss of 0.47
# 		-Evaluation_categorical_accuracy of 0.88
#
# 	-Score for fold 4:
# 		-Evaluation_loss of 0.41
# 		-Evaluation_categorical_accuracy of 0.89

# %% [markdown]
# ### Boxplot

# %%
import seaborn as sns

loss_scores = [scores[i][0] for  i in range(len(scores))]
accuracy_scores = [scores[i][1] for  i in range(len(scores))]

folds_loss = sum(loss_scores) / len(scores)
folds_accuracy = sum(accuracy_scores) / len(scores) 

sns.set(style="darkgrid")
sns.set(rc={'figure.figsize':(22,16)})

sns.boxplot(x=accuracy_scores, color='skyblue').set(xlabel='Accuracy', ylabel='DeepKnob')
plt.show()

print(f'\nAverage Evaluation Loss: {folds_loss:.3f}')
print(f'Average Evaluation Accuracy: {folds_accuracy:.3f}')
# Out:
# Average Evaluation Loss: 0.500
# Average Evaluation Accuracy: 0.853
